# %% [markdown]
# ## 웹 스크래핑

# %% [markdown]
# * 웹 사이트의 내용을 가져와 원하는 형태로 가공하는 것
# * 어디에서 어느 정보를 가져올 것인지 정해야 함
# * 웹 문서를 모두 가져온 후 원하는 부분만 추출

# %% [markdown]
# ### 웹 사이트 접근 시 주의사항
# * 웹 사이트의 이용규약을 확인하고 지킨다
# * robots.tx와 robots 메타 태그의 접근 제한 사항을 지킨다.
# * 제한이 없더라도 상대 서버에 부하가 가지 않을 정도의 속도로 접근
# * rel="nofollow"가 설정되어 있으면 크롤러로 접근하지 않는다
# * 크롤링을 거부하는 조치가 있으면 즉시 크롤링을 멈추고, 추출한 정보를 삭제

# %% [markdown]
# ### 수집한 데이터를 다룰 때 중의사항
# * 저작권에 문제가 있으면 개인적인 용도로만 사용
# * 수집한 데이터를 기반으로 검색 서비스를 제공하는 경우, 웹 사이트와 API등의 사용 규약을 확인하고 문제 없을 시에만 제공
# * 이용 규약이 따로 없을 때에도 상대방에게 확인한 뒤 데이터를 공개

# %% [markdown]
# ### 정규표현식

# %%
# 필요 패키지 불러오기
import urllib.request
# 정규표현식 모듈
import re

# %%
# 삼성전자의 주식정보 파싱
url = "https://finance.naver.com/item/main.nhn?code=005930"
html = urllib.request.urlopen(url)
html_contents = str(html.read().decode("ms949"))

# %%
html_contents
# Out:
# '\n\n\t\n\t\n\t\n\t\n<html lang=\'ko\'>\n<head>\n\n\n\t\n\t\t<title>삼성전자 : 네이버 증권</title>\n\t\n\t\n\n\n\n\n\n\t\n\t\n\t\t<meta http-equiv="Content-Type" content="text/html; charset=utf-8" />\n\t\n\n\n<meta http-equiv="Content-Script-Type" content="text/javascript">\n<meta http-equiv="Content-Style-Type" content="text/css">\n<meta name="apple-mobile-web-app-title" content="네이버 증권" />\n\n\n\n\n\n\t\n    \n        <meta property="og:url" content="https://finance.naver.com/item/main.naver?code=005930"/>\n        \n\t\t\t\n\t\t    \n\t\t    \t<meta property="og:title" content="삼성전자 - 네이버 증권 : 네이버 증권"/>\n\t\t     \n\t\t\n\t\t\n\t\t\t\n\t\t\t   <meta property="og:description" content="관심종목의 실시간 주가를 가장 빠르게 확인하는 곳"/>\n\t\t    \n\t\t    \n\t\t\n\t\t \n\t\t\t\n\t\t\t    <meta property="og:image" content="https://ssl.pstatic.net/static/m/stock/im/2016/08/og_stock-200.png"/>\n\t\t    \n\t\t    \n\t\t\n    \n\n<meta property="og:type" content="article"/>\n<meta property="og:article:thumbnailUrl" content=""/>\n<meta property="og:article:author" content="네이버 증권"/>\n<meta property="og:article:author:url" content="http://FINANCE.NAVER.COM"/>\n\n\n\n\n\n\n<link rel=\'stylesheet\' type=\'text/css\' href=\'https://ssl.pstatic.net/imgstock/static.pc/20230321170048/css/finance_header.css\'>\n\n\t\n\t\n\t\n\t\n\t\t\n\t\t<link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/imgstock/static.pc/20230321170048/css/newstock.css">\n\t\t<link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/imgstock/static.pc/20230321170048/css/common.css">\n\t\t<link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/imgstock/static.pc/20230321170048/css/layout.css">\n\t\t<link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/imgstock/static.pc/20230321170048/css/main.css">\n\t\t<link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/imgstock/static.pc/20230321170048/css/newstock2.css">\n\t\t<link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/imgstock/static.pc/20230321170048/css/newstock3.css">\n\t\t<link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/imgstock/static.pc/20230321170048/css/world.css">\n\t\t\n\t\t\t\n\t\t\t\n\t\t\t\t<script type="text/javascript" src="https://ssl.pstatic.net/imgstock/static.pc/20230321170048/js/jindo.min.ns.1.5.3.euckr.js"></script>\n\t\t\t\t<script type="text/javascript" src="https://ssl.pstatic.net/imgstock/static.pc/20230321170048/js/release/common.js"></script>\n\t\t\t\t<script type="text/javascript" src="https://ssl.pstatic.net/imgstock/static.pc/20230321170048/js/jindoComponent/jindo.Component.1.0.3.js"></script>\n\t\t\t\t<script type="text/javascript" src="https://ssl.pstatic.net/imgstock/static.pc/20230321170048/js/nhn.autocomplete.stock.js"></script>\n\t\t\t\n\t\t\n\n\t\t\n\t\n\n<script>\n\tvar ieVersion = (function () {\n        var version = -1;\n        if (\n          navigator.appName == \'Microsoft Internet Explorer\' &&\n          navigator.userAgent.toLowerCase().indexOf(\'msie\') != -1 &&\n          new RegExp(\'MSIE ([0-9]{1,}[\\./0-9]{0,})\').exec(navigator.userAgent) != null\n        ) {\n          version = parseInt(RegExp.$1);\n        }\n        return version;\n      })();\n</script>\n\t\n\t<!-- smart channel 광고 -->\n\t<script async src="https://ssl.pstatic.net/tveta/libs/glad/prod/gfp-core.js">\n\t\t</script>\n\t<script type="text/javascript">\n\t\t(function(){\n\t\t\tif (ieVersion === -1 || ieVersion > 10) {\n\t\t\t\twindow.gladsdk = window.gladsdk || { cmd: [] };\n\n\t\t\t\tgladsdk.cmd.push(function() {\n\t\t\t\t\t\tgladsdk.defineAdSlot({\n\t\t\t\t\t\t\tadUnitId: "p_nf_stock",\n\t\t\t\t\t\t\tadSlotElementId: "_SmartChannelTopBanner",\n\t\t\t\t\t\t\tuct: "KR",\n\t\t\t\t\t\t\tcustomParam: {\n\t\t\t\t\t\t\t\tcalp: \n\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t"home"\n\t\t\t\t\t\t\t},\n\t\t\t\t\t\t});\n\n\n\n\t\t\t\t\t\tglads ...

# %%
# 첫번째 HTML 패턴
stock_results = re.findall("(\<dl class=\"blind\")([\s\S]+?)(\</dl\>)", html_contents)

# 튜플형태로 리턴
stock_results
# Out:
# [('<dl class="blind"',
#   '>\n\t        <dt>종목 시세 정보</dt>\n\t        <dd>2023년 04월 03일 16시 11분 기준 장마감</dd>\n\t        <dd>종목명 삼성전자</dd>\n\t        <dd>종목코드 005930 코스피</dd>\n\t        <dd>현재가 63,100 전일대비 하락 900 마이너스 1.41 퍼센트</dd>\n\t        <dd>전일가 64,000</dd>\n\t        <dd>시가 64,000</dd>\n\t        <dd>고가 64,000</dd>\n\t        <dd>상한가 83,200</dd>\n\t        <dd>저가 63,000</dd>\n\t        <dd>하한가 44,800</dd>\n\t        <dd>거래량 11,941,193</dd>\n\t        <dd>거래대금 755,268백만</dd>\n        ',
#   '</dl>'),
#  ('<dl class="blind"',
#   '>\n                        <dt><strong>삼성전자</strong></dt>\n                        <dd>오늘의시세 63,100 포인트</dd>\n                        <dd>900 포인트 하락</dd>\n                        <dd>1.41% 마이너스</dd>\n                ',
#   '</dl>')]

# %%
# 두 개의 튜플 값 중 첫번째 패턴
samsung_stock = stock_results[0]
samsung_stock
# Out:
# ('<dl class="blind"',
#  '>\n\t        <dt>종목 시세 정보</dt>\n\t        <dd>2023년 04월 03일 16시 11분 기준 장마감</dd>\n\t        <dd>종목명 삼성전자</dd>\n\t        <dd>종목코드 005930 코스피</dd>\n\t        <dd>현재가 63,100 전일대비 하락 900 마이너스 1.41 퍼센트</dd>\n\t        <dd>전일가 64,000</dd>\n\t        <dd>시가 64,000</dd>\n\t        <dd>고가 64,000</dd>\n\t        <dd>상한가 83,200</dd>\n\t        <dd>저가 63,000</dd>\n\t        <dd>하한가 44,800</dd>\n\t        <dd>거래량 11,941,193</dd>\n\t        <dd>거래대금 755,268백만</dd>\n        ',
#  '</dl>')

# %%
# 세 개의 튜플 값 중 두번째 패턴
samsung_index = samsung_stock[1]
samsung_index
# Out:
# '>\n\t        <dt>종목 시세 정보</dt>\n\t        <dd>2023년 04월 03일 16시 11분 기준 장마감</dd>\n\t        <dd>종목명 삼성전자</dd>\n\t        <dd>종목코드 005930 코스피</dd>\n\t        <dd>현재가 63,100 전일대비 하락 900 마이너스 1.41 퍼센트</dd>\n\t        <dd>전일가 64,000</dd>\n\t        <dd>시가 64,000</dd>\n\t        <dd>고가 64,000</dd>\n\t        <dd>상한가 83,200</dd>\n\t        <dd>저가 63,000</dd>\n\t        <dd>하한가 44,800</dd>\n\t        <dd>거래량 11,941,193</dd>\n\t        <dd>거래대금 755,268백만</dd>\n        '

# %%
# 주식 정보만 추출
index_list = re.findall("(\<dd\>)([\s\S]+?)(\</dd\>)", samsung_index)
index_list
# Out:
# [('<dd>', '2023년 04월 03일 16시 11분 기준 장마감', '</dd>'),
#  ('<dd>', '종목명 삼성전자', '</dd>'),
#  ('<dd>', '종목코드 005930 코스피', '</dd>'),
#  ('<dd>', '현재가 63,100 전일대비 하락 900 마이너스 1.41 퍼센트', '</dd>'),
#  ('<dd>', '전일가 64,000', '</dd>'),
#  ('<dd>', '시가 64,000', '</dd>'),
#  ('<dd>', '고가 64,000', '</dd>'),
#  ('<dd>', '상한가 83,200', '</dd>'),
#  ('<dd>', '저가 63,000', '</dd>'),
#  ('<dd>', '하한가 44,800', '</dd>'),
#  ('<dd>', '거래량 11,941,193', '</dd>'),
#  ('<dd>', '거래대금 755,268백만', '</dd>')]

# %%
# 세 개의 튜플 값중 두번째 값
for index in index_list:
    print(index[1])
# Out:
# 2023년 04월 03일 16시 11분 기준 장마감
# 종목명 삼성전자
# 종목코드 005930 코스피
# 현재가 63,100 전일대비 하락 900 마이너스 1.41 퍼센트
# 전일가 64,000
# 시가 64,000
# 고가 64,000
# 상한가 83,200
# 저가 63,000
# 하한가 44,800
# 거래량 11,941,193
# 거래대금 755,268백만

# %% [markdown]
# ## 웹 크롤링

# %% [markdown]
# * 웹 크롤러가 하는 작업 - 웹 크롤러는 조직적, 자동화 된 방법으로 웹을 탐색하는 프로그램, 웹 크롤링 혹은 스파이더링이라고도 불림
# * 검색엔진과 같은 여러 사이트에서 사이트의 최신 상태를 유지하기 위해 웹 크롤링을 함
# * 방문한 사이트의 모든 페이지의 복사본을 생성하는 데 사용되며, 생성된 페이지를 인덱싱 함
# * 웹 크롤러는 봇이나 소프트웨어의 한 형태

# %%
# 필요 패키지 불러오기
# !pip install selenium

# %%
from selenium import webdriver

# %%
# 크롬 드라이버 활용
# 크롬 드라이버 경로가 정확히 등록되어야 함
driver = webdriver.Chrome('D:/chromedriver/chromedriver.exe')
# Out:
# C:\Users\chunc\AppData\Local\Temp\ipykernel_41156\706859011.py:3: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('D:/chromedriver/chromedriver.exe')

# %%
# URL접속
url = 'https://www.naver.com'
driver.get(url)

# 웹 페이지 HTML 다운로드
html = driver.page_source
html
# Out:
# '<html lang="ko" data-dark="false" data-useragent="Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/111.0.0.0 Safari/537.36"><head><script async="" type="text/javascript" src="https://ssl.pstatic.net/tveta/libs/ndpsdk/prod/ndp-core.js"></script> <meta charset="utf-8"> <title>NAVER</title> <meta http-equiv="X-UA-Compatible" content="IE=edge"> <meta name="viewport" content="width=1190"> <meta name="apple-mobile-web-app-title" content="NAVER"> <meta name="robots" content="index,nofollow"> <meta name="description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"> <meta property="og:title" content="네이버"> <meta property="og:url" content="https://www.naver.com/"> <meta property="og:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta property="og:description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"> <meta name="twitter:card" content="summary"> <meta name="twitter:title" content=""> <meta name="twitter:url" content="https://www.naver.com/"> <meta name="twitter:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta name="twitter:description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요">  <link rel="stylesheet" href="https://pm.pstatic.net/dist/css/nmain.20230302.css"> <link rel="stylesheet" href="https://ssl.pstatic.net/sstatic/search/pc/css/sp_autocomplete_220526.css"> <link rel="shortcut icon" type="image/x-icon" href="/favicon.ico?1">  <link rel="apple-touch-icon" sizes="114x114" href="https://s.pstatic.net/static/www/u/2014/0328/mma_204243574.png"> <link rel="apple-touch-icon" href="https://s.pstatic.net/static/www/u/2014/0328/mma_20432863.png"> <script>window.nmain=window.nmain||{},window.nmain.supportFlicking=!1;var nsc="navertop.v4",ua=navigator.userAgent,useIeJSFlag="1";window.nmain.isIE="0"===useIeJSFlag,document.getElementsByTagName("html")[0].setAttribute("data-useragent",ua),window.nmain.isIE&&(Object.create=function(n){function e(){}return e.prototype=n,new e})</script> <script>var darkmode= false;window.naver_corp_da=window.naver_corp_da||{main:{}},window.naver_corp_da.main=window.naver_corp_da.main||{},window.naver_corp_da.main.darkmode=darkmode,window.gladsdk=window.gladsdk||{cmd:[]},window.gladsdk.cmd.push((function(){window.gladsdk.setHostMeta("theme",darkmode?"dark":"light")})),window.ndpsdk=window.ndpsdk||{cmd:[],polyfill:{cmd:[]}},window.ndpsdk.cmd.push((function(){window.ndpsdk.setHostMeta("theme",darkmode?"dark":"light")}))</script>  <script async="" src="https://ssl.pstatic.net/tveta/libs/glad/prod/gfp-core.js"></script> <script async="" src="https://ssl.pstatic.net/tveta/libs/ndpsdk/prod/ndp-loader.js"></script>  <script> window.nmain.gv = {  isLogin: false,\nuseId: null,   daInfo: {"BEAUTY":{"menu":"BEAUTY","childMenu":"","adType":"singleDom","multiDomAdUrl":"","multiDomUnit":"","infoList":[{"adposId":"1000163","singleDomAdUrl":"https://siape.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_beauty_1","tb":"BEAUTY_1","unit":"SU10595","calp":"-"},"type":{"position":"abs","positionIndex":4,"subject":"contents"},"dom":null},{"adposId":"1000164","singleDomAdUrl":"https://siape.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_beauty_2","tb":"BEAUTY_1","unit":"SU10596","calp":"-"},"type":{"position":"abs","positionIndex":8,"subject":"contents"},"dom":null}]},"LIVING":{"menu":"LIVING","childMenu":"","adType":"singleDom","multiDomAdUrl":"","multiDomUnit":"","infoList":[{"adposId":"1000183","singleDomAdUrl":"https://siape.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_living_1","tb":"LIVING_1","unit":"SU10597","calp":"-"},"type":{"position":"abs","positionIndex":4,"subject":"contents"},"dom":null},{"adposId":"1000184","singleDomAdUrl":"https://siape.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_living_2","tb":"LIVING_1","unit":"SU10606","calp":"-"},"type":{"position":"abs","positionIndex":8,"subject":"contents"},"dom":null}]},"LIVINGHOME":{"menu":"LIVINGHOME","childMenu":"" ...

# %% [markdown]
# ### 크롤링 연습(멜론차트)

# %%
# 필요패키지 설치
# !pip install beautifulsoup4

# %%
# 크롤링 연습(멜론)
from selenium import webdriver
driver = webdriver.Chrome('D:/chromedriver/chromedriver.exe')
url = 'https://www.melon.com/chart/day/index.htm'
driver.get(url)
# Out:
# C:\Users\chunc\AppData\Local\Temp\ipykernel_41156\2861460903.py:3: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('D:/chromedriver/chromedriver.exe')

# %%
# BeautifulSoup패키지 모듈을 사용 멜론 일간 차트 파싱
from bs4 import BeautifulSoup
html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')

# %%
# 일간차트 1~50위항목을 불러오기
songs = soup.select('#lst50')
print(len(songs))
print(songs[0])
# Out:
# 50
# <tr class="lst50" data-song-no="36318125" id="lst50">
# <td><div class="wrap t_right"><input class="input_check" name="input_check" title="Kitsch 곡 선택" type="checkbox" value="36318125"/></div></td>
# <td><div class="wrap t_center"><span class="rank">1</span><span class="none">위</span></div></td>
# <!-- 차트순위 추가 -->
# <td><div class="wrap">
# <span class="rank_wrap" title="순위 동일">
# <span class="bullet_icons rank_static"><span class="none">순위 동일</span></span>
# <span class="none">0</span>
# </span>
# </div></td>
# <td><div class="wrap">
# <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('11211297');" title="Kitsch">
# <img alt="Kitsch - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="https://cdnimg.melon.co.kr/cm2/album/images/112/11/297/11211297_20230327114349_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
# <span class="bg_album_frame"></span>
# </a>
# </div></td>
# <td><div class="wrap">
# <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('36318125');" title="Kitsch 곡정보"><span class="none">곡정보</span></a>
# </div></td>
# <td><div class="wrap">
# <div class="wrap_song_info">
# <div class="ellipsis rank01"><span>
# <a href="javascript:melon.play.playSong('19041201',36318125);" title="Kitsch 재생">Kitsch</a>
# </span></div><br/>
# <div class="ellipsis rank02">
# <a href="javascript:melon.link.goArtistDetail('3055146');" title="IVE (아이브) - 페이지 이동">IVE (아이브)</a><span class="checkEllipsis" style="display: none;"><a href="javascript:melon.link.goArtistDetail('3055146');" title="IVE (아이브) - 페이지 이동">IVE (아이브)</a></span>
# </div>
# </div>
# </div></td>
# <td><div class="wrap">
# <div class="wrap_song_info">
# <div class="ellipsis rank03">
# <a href="javascript:melon.link.goAlbumDetail('11211297');" title="Kitsch - 페이지 이동">Kitsch</a>
# </div>
# </div>
# </div></td>
# <td><div class="wrap">
# <button class="button_etc like" data-song-menuid="19041201" data-song-no="36318125" title="Kitsch 좋아요" type="button"><span class="odd_span">좋아요</span>
# <span class="cnt">
# <span class="none">총건수</span>
# 58,753</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons play" onclick="melon.play.playSong('19041201',36318125);" title="듣기" type="button"><span class="none">듣기</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons scrap" onclick="melon.play.addPlayList('36318125');" title="담기" type="button"><span class="none">담기</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons download" onclick="melon.buy.goBuyProduct('frm', '36318125', '3C0001', '','0', '19041201');" title="다운로드" type="button"><span class="none">다운로드</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons video" onclick="melon.link.goMvDetail('19041201', '36318125','song');" title="뮤직비디오" type="button"><span class="none">뮤직비디오</span></button>
# </div></td>
# </tr>

# %%
# 일간차트 1위곡의 제목 추출
title = soup.select('div.ellipsis.rank01 > span > a')[0].text
title
# Out:
# 'Kitsch'

# %%
# 일간차트 1위곡의 가수그룹 추출
singer = soup.select('div.ellipsis.rank02 > a')[0].text
singer
# Out:
# 'IVE (아이브)'

# %%
# for문을 사용하여 차트50위까지의 곡들의 제목과 가수 출력
for song in songs:
    title = song.select('div.ellipsis.rank01 > span > a')[0].text
    singer = song.select('div.ellipsis.rank02 > a')[0].text
    print(title, singer, sep = ' | ')
# Out:
# Kitsch | IVE (아이브)
# Ditto | NewJeans
# Hype boy | NewJeans
# OMG | NewJeans
# 꽃 | 지수 (JISOO)
# Nostalgia | 우디 (Woody)
# Teddy Bear | STAYC(스테이씨)
# 사건의 지평선 | 윤하 (YOUNHA)
# I Don't Think That I Like Her | Charlie Puth
# CHRISTIAN | Zior Park
# 파이팅 해야지 (Feat. 이영지) | 부석순 (SEVENTEEN)
# 심(心) | DK(디셈버)
# Attention | NewJeans
# After LIKE | IVE (아이브)
# 사랑하기 싫어 | 지아
# ANTIFRAGILE | LE SSERAFIM (르세라핌)
# 밤이 무서워요 (Lonely Night) | 주주 시크릿
# Love Me Like This | NMIXX
# LOVE DIVE | IVE (아이브)
# 사랑인가 봐 | 멜로망스
# 벚꽃 엔딩 | 버스커 버스커
# NIGHT DANCER | imase
# Like Crazy | 지민
# 나비무덤 | 포맨 (4MEN)
# 너를 보는게 지친 하루에 | 송하예
# Dangerously | Charlie Puth
# 봄 사랑 벚꽃 말고 | HIGH4 (하이포)
# 사랑은 늘 도망가 | 임영웅
# 결국엔 너에게 닿아서 | WSG워너비 (가야G)
# Candy | NCT DREAM
# 건물 사이에 피어난 장미 (Rose Blossom) | H1-KEY (하이키)
# VIBE (feat. Jimin of BTS) | 태양
# 너의 모든 순간 | 성시경
# Nxde | (여자)아이들
# Expectations | Anne-Marie
# Say I Love You | 우디 (Woody)
# Monologue | 테이
# That's Hilarious | Charlie Puth
# 새삥 (Prod. ZICO) (Feat. 호미들) | 지코 (ZICO)
# 해요 (2022) | #안녕
# Cookie | NewJeans
# 우연히 봄 | 로꼬
# 취중고백 | 김민석 (멜로망스)
# on the street (with J. Cole) | j-hope
# STAY | The Kid LAROI
# 그라데이션 | 10CM
# Shut Down | BLACKPINK
# 내가 아니라도 | 주호
# TOMBOY | (여자)아이들
# 정이라고 하자 (Feat. 10CM) | BIG Naughty (서동현)

# %%
# 1~100위 차트 모두 출력
songs = soup.select('.lst50, .lst100')
print(songs[0])
# Out:
# <tr class="lst50" data-song-no="36318125" id="lst50">
# <td><div class="wrap t_right"><input class="input_check" name="input_check" title="Kitsch 곡 선택" type="checkbox" value="36318125"/></div></td>
# <td><div class="wrap t_center"><span class="rank">1</span><span class="none">위</span></div></td>
# <!-- 차트순위 추가 -->
# <td><div class="wrap">
# <span class="rank_wrap" title="순위 동일">
# <span class="bullet_icons rank_static"><span class="none">순위 동일</span></span>
# <span class="none">0</span>
# </span>
# </div></td>
# <td><div class="wrap">
# <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('11211297');" title="Kitsch">
# <img alt="Kitsch - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="https://cdnimg.melon.co.kr/cm2/album/images/112/11/297/11211297_20230327114349_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
# <span class="bg_album_frame"></span>
# </a>
# </div></td>
# <td><div class="wrap">
# <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('36318125');" title="Kitsch 곡정보"><span class="none">곡정보</span></a>
# </div></td>
# <td><div class="wrap">
# <div class="wrap_song_info">
# <div class="ellipsis rank01"><span>
# <a href="javascript:melon.play.playSong('19041201',36318125);" title="Kitsch 재생">Kitsch</a>
# </span></div><br/>
# <div class="ellipsis rank02">
# <a href="javascript:melon.link.goArtistDetail('3055146');" title="IVE (아이브) - 페이지 이동">IVE (아이브)</a><span class="checkEllipsis" style="display: none;"><a href="javascript:melon.link.goArtistDetail('3055146');" title="IVE (아이브) - 페이지 이동">IVE (아이브)</a></span>
# </div>
# </div>
# </div></td>
# <td><div class="wrap">
# <div class="wrap_song_info">
# <div class="ellipsis rank03">
# <a href="javascript:melon.link.goAlbumDetail('11211297');" title="Kitsch - 페이지 이동">Kitsch</a>
# </div>
# </div>
# </div></td>
# <td><div class="wrap">
# <button class="button_etc like" data-song-menuid="19041201" data-song-no="36318125" title="Kitsch 좋아요" type="button"><span class="odd_span">좋아요</span>
# <span class="cnt">
# <span class="none">총건수</span>
# 58,753</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons play" onclick="melon.play.playSong('19041201',36318125);" title="듣기" type="button"><span class="none">듣기</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons scrap" onclick="melon.play.addPlayList('36318125');" title="담기" type="button"><span class="none">담기</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons download" onclick="melon.buy.goBuyProduct('frm', '36318125', '3C0001', '','0', '19041201');" title="다운로드" type="button"><span class="none">다운로드</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons video" onclick="melon.link.goMvDetail('19041201', '36318125','song');" title="뮤직비디오" type="button"><span class="none">뮤직비디오</span></button>
# </div></td>
# </tr>

# %%
# 추가적으로 앨범병까지 출력
album = soup.select('div.ellipsis.rank03 > a')[0].text
album
# Out:
# 'Kitsch'

# %%
for song in songs:
    title = song.select('div.ellipsis.rank01 > span > a')[0].text
    singer = song.select('div.ellipsis.rank02 > a')[0].text
    album = song.select('div.ellipsis.rank03 > a')[0].text
    print(title, singer, album, sep = ' | ')
# Out:
# Kitsch | IVE (아이브) | Kitsch
# Ditto | NewJeans | NewJeans 'OMG'
# Hype boy | NewJeans | NewJeans 1st EP 'New Jeans'
# OMG | NewJeans | NewJeans 'OMG'
# 꽃 | 지수 (JISOO) | ME
# Nostalgia | 우디 (Woody) | Nostalgia
# Teddy Bear | STAYC(스테이씨) | Teddy Bear
# 사건의 지평선 | 윤하 (YOUNHA) | YOUNHA 6th Album Repackage 'END THEORY : Final Edition'
# I Don't Think That I Like Her | Charlie Puth | CHARLIE
# CHRISTIAN | Zior Park | WHERE DOES SASQUATCH LIVE? PART 1
# 파이팅 해야지 (Feat. 이영지) | 부석순 (SEVENTEEN) | 부석순 1st Single Album 'SECOND WIND'
# 심(心) | DK(디셈버) | 심(心)
# Attention | NewJeans | NewJeans 1st EP 'New Jeans'
# After LIKE | IVE (아이브) | After LIKE
# 사랑하기 싫어 | 지아 | 사랑하기 싫어
# ANTIFRAGILE | LE SSERAFIM (르세라핌) | ANTIFRAGILE
# 밤이 무서워요 (Lonely Night) | 주주 시크릿 | 밤이 무서워요 (Lonely Night)
# Love Me Like This | NMIXX | expérgo
# LOVE DIVE | IVE (아이브) | LOVE DIVE
# 사랑인가 봐 | 멜로망스 | 사랑인가 봐 (사내맞선 OST 스페셜 트랙)
# 벚꽃 엔딩 | 버스커 버스커 | 버스커 버스커 1집
# NIGHT DANCER | imase | NIGHT DANCER
# Like Crazy | 지민 | FACE
# 나비무덤 | 포맨 (4MEN) | 나비무덤
# 너를 보는게 지친 하루에 | 송하예 | 너를 보는게 지친 하루에
# Dangerously | Charlie Puth | Nine Track Mind (Deluxe Edition)
# 봄 사랑 벚꽃 말고 | HIGH4 (하이포) | 봄 사랑 벚꽃 말고
# 사랑은 늘 도망가 | 임영웅 | 신사와 아가씨 OST Part.2
# 결국엔 너에게 닿아서 | WSG워너비 (가야G) | 결국엔 너에게 닿아서
# Candy | NCT DREAM | Candy - Winter Special Mini Album
# 건물 사이에 피어난 장미 (Rose Blossom) | H1-KEY (하이키) | H1-KEY 1st Mini Album [Rose Blossom]
# VIBE (feat. Jimin of BTS) | 태양 | VIBE (feat. Jimin of BTS)
# 너의 모든 순간 | 성시경 | 별에서 온 그대 OST Part.7
# Nxde | (여자)아이들 | I love
# Expectations | Anne-Marie | Expectations
# Say I Love You | 우디 (Woody) | Say I Love You (Re : WIND 4MEN Vol.04)
# Monologue | 테이 | Monologue
# That's Hilarious | Charlie Puth | CHARLIE
# 새삥 (Prod. ZICO) (Feat. 호미들) | 지코 (ZICO) | 스트릿 맨 파이터(SMF) Original Vol.3 (계급미션)
# 해요 (2022) | #안녕 | 해요 (2022)
# Cookie | NewJeans | NewJeans 1st EP 'New Jeans'
# 우연히 봄 | 로꼬 | 냄새를 보는 소녀 OST Part.2
# 취중고백 | 김민석 (멜로망스) | 취중고백
# on the street (with J. Cole) | j-hope | on the street (with J. Cole)
# STAY | The Kid LAROI | Stay
# 그라데이션 | 10CM | 5.3
# Shut Down | BLACKPINK | BORN PINK
# 내가 아니라도 | 주호 | 내가 아니라도
# TOMBOY | (여자)아이들 | I NEVER DIE
# 정이라고 하자 (Feat. 10CM) | BIG Naughty (서동현) | 정이라고 하자
# Young, Dumb, Stupid | NMIXX | expérgo
# 그때 그 순간 그대로 (그그그) | WSG워너비 (가야G) | WSG워너비 1집
# Unholy | Sam Smith | Gloria
# 다정히 내 이름을 부르면 | 경서예지 | 다정히 내 이름을 부르면 (경서예지 x 전건호)
# Pink Venom | BLACKPINK | BORN PINK
# 봄날 | 방탄소년단 | YOU NEVER WALK ALONE
# 되돌리다 | 먼데이 키즈 (Monday Kiz) | 되돌리다
# Set Me Free Pt.2 | 지민 | FACE
# FEARLESS | LE SSERAFIM (르세라핌) | FEARLESS
# 우리들의 블루스 | 임영웅 | IM HERO
# 오르트구름 | 윤하 (YOUNHA) | YOUNHA 6th Album 'END THEORY'
# Dynamite | 방탄소년단 | Dynamite (DayTime Version)
# NOT SORRY (Feat. pH-1) (Prod. by Slom) | 이영지 | 쇼미더머니 11 Episode 3
# ELEVEN | IVE (아이브) | ELEVEN
# Poppy (Korean Ver.) | STAYC(스테이씨) | Teddy Bear
# 사랑이라 믿었던 것들은 (Feat. 이수현) | BIG Naughty (서동현) | 호프리스 로맨틱
# 나의 X에게 | 경서 | 나의 X에게
# Rush Hour (Feat. j-hope of BTS) | Crush | Rush Hour
# 나만, 봄 | 볼빨간사춘기 | 사춘기집Ⅰ 꽃기운
# 모든 날, 모든 순간 (Every day, Every Moment) | 폴킴 | '키스 먼저 할까요?' OST Part.3
# 그대를 알고 | 송하예 | 그대를 알고
# 혼자가 아닌 나 | 정효빈 | 혼자가 아닌 나
# 딱 10CM만 | 10CM | 딱 10CM만
# 잘가요 | 주호 | 잘가요
# 아모르 파티 | 이홍기 (FT아일랜드) | 아모르 파티
# That That (prod. & feat. SUGA of BTS) | 싸이 (PSY) | 싸다9
# Sugar Rush Ride | 투모로우바이투게더 | 이름의 장: TEMPTATION
# Off My Face | Justin Bieber | Justice (The Complete Edition)
# 그대라는 사치 | 임창정 | 그대라는 사치
# Dreamers [Music from the FIFA World Cup Qatar 2022 Official Soundtrack] (Feat. FIFA Sound) | 정국 | Dreamers [Music from the FIFA World Cup Qatar 2022 Official Soundtrack]
# 너와 함께 | 김민석 (멜로망스) | 너와 함께
# 다시 만날 수 있을까 | 임영웅 | IM HERO
# Butter | 방탄소년단 | Butter
# 마지막 사랑 | 신예영 | 마지막 사랑
# London Boy | 임영웅 | Polaroid
# 이제 나만 믿어요 | 임영웅 | 내일은 미스터트롯 우승자 특전곡
# 그댄 행복에 살텐데 (2022) | 최유리 | 그댄 행복에 살텐데 (2022)
# 자격지심 (Feat. ZICO) | BE'O (비오) | FIVE SENSES
# LOVE me | BE'O (비오) | LOVE me
# Polaroid | 임영웅 | Polaroid
# 봄이 좋냐?? | 10CM | 3.2
# 봄여름가을겨울 (Still Life) | BIGBANG (빅뱅) | 봄여름가을겨울 (Still Life)
# 네가 보고 싶은 건 자연스러운 거겠지 | 신예영 | 혼잣말 獨白
# 밤하늘의 별을(2020) | 경서 | 밤하늘의 별을(2020)
# All Eyes On Me | 지수 (JISOO) | ME
# Permission to Dance | 방탄소년단 | Butter / Permission to Dance
# Love story | 볼빨간사춘기 | Seoul
# 흔들리는 꽃들 속에서 네 샴푸향이 느껴진거야 | 장범준 | 멜로가 체질 OST Part 3
# 무지개 | 임영웅 | IM HERO
# 내 기쁨은 너가 벤틀리를 끄는 거야 | 김승민 | PROTOTYPE RESEARCH #0063

# %%
# selenium만을 활용한 크롤링 연습
# 모듈이 계속 업데이트가 되므로 함수명이 변경될 수도 있다
from selenium.webdriver.common.by import By
driver = webdriver.Chrome('D:/chromedriver/chromedriver.exe')
url = 'https://www.melon.com/chart/day/index.htm'
driver.get(url)
# Out:
# C:\Users\chunc\AppData\Local\Temp\ipykernel_41156\2337218689.py:4: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('D:/chromedriver/chromedriver.exe')

# %%
songs = driver.find_elements(By.CSS_SELECTOR, '#lst50')
songs
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="043f9ccc7b181754f67df487ceca659f", element="8f34c9c7-817b-4d2d-ac1c-f004b9cbed8c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="043f9ccc7b181754f67df487ceca659f", element="342c14ea-a0c4-45d3-816b-57dcc835e9f9")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="043f9ccc7b181754f67df487ceca659f", element="acdf3dad-3569-46bf-8b26-20e5f60721de")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="043f9ccc7b181754f67df487ceca659f", element="c882ecaf-17b1-4e18-8a03-4a85be7669b0")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="043f9ccc7b181754f67df487ceca659f", element="6d625fd5-3d15-4dc2-9f2e-8bf55a097886")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="043f9ccc7b181754f67df487ceca659f", element="643b4f1b-c804-4d62-a46e-9fd9fb438eb9")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="043f9ccc7b181754f67df487ceca659f", element="ba8764e6-09dd-426e-a862-08dac55db11c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="043f9ccc7b181754f67df487ceca659f", element="5eef6d9d-aa94-46ee-b892-8fc17291940f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="043f9ccc7b181754f67df487ceca659f", element="adae52a5-07cf-4d2f-a6ad-b0b402e1b0fb")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="043f9ccc7b181754f67df487ceca659f", element="9b6d9ad3-e1fe-4270-b3a6-6fff95b1907a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="043f9ccc7b181754f67df487ceca659f", element="afbff474-5d33-44c7-adc5-5e70264c2952")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="043f9ccc7b181754f67df487ceca659f", element="76f639ad-4994-41e7-a673-9dc5952b8ca7")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="043f9ccc7b181754f67df487ceca659f", element="f632cddb-b3e9-4294-82ef-7c9f1e2dab34")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="043f9ccc7b181754f67df487ceca659f", element="ffdda268-74b9-4800-9c97-2a7cf46033a8")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="043f9ccc7b181754f67df487ceca659f", element="6161fc26-2940-48ef-8e25-ead82281c330")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="043f9ccc7b181754f67df487ceca659f", element="cfd33557-1073-4faf-8f9f-42d96ce71c7d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="043f9ccc7b181754f67df487ceca659f", element="6dbbab2f-4d8c-49f6-ad09-76128bce79e0")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="043f9ccc7b181754f67df487ceca659f", element="1fc5f92a-7bb2-41aa-9199-25c744915f67")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="043f9ccc7b181754f67df487ceca659f", element="89c93090-e206-4499-bfb8-f0773f1967fe")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="043f9ccc7b181754f67df487ceca659f", element="f0189d35-09ca-4e83-963e-d60286ebd99c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="043f9ccc7b181754f67df487ceca659f", element="2274c937-a23d-4cd2-b5c5-b526b98fe194")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="043f9ccc7b181754f67df487ceca659f", element="cc8830ed-3495-45f7-adb5-055a79c627e7")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="043f9ccc7b181754f67df487ceca659f", element="cb4f99a9-2b32-4e8c-8cc3-ca639b13008b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="043f9ccc7b181754f67df487ceca659f", element="6c7a4279-e4ae-4194-95b8-b676c9d488a4")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="043f9ccc7b181754f67df487ceca659f", element="1787fe6f-f811-4144-9509-5d6e14155abd")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="043f9ccc7b181754f67df487ceca659f", element="f308c343-0cfe-4382-b0de-70a7bdaae485")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="043f9ccc7b181754f67df487ceca659f", element="36dca067-ef79-4974-a7f2-9c0aa7964183")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="043f9ccc7b181754f67df487ceca659f", element="5ed0505d-1cd2-41da-af26-87af93bbb220")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="043f9ccc7b181754f67df487ceca659f", element="5845bef3-d847-4a48-a8b9-39b5d1acff02")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="043f9ccc7b181754f67df487ceca659f", element="c75c7c76-59ec-4f9d-b3a3-64bce25c6e27")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="043f9ccc7b181754f67df487ceca659f", element="3bb1a3a3-5d14-4d00-a9ce-124ffa1957db")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="043f9ccc7b181754f67df487ceca659f", element="ae2ad50f-bda4-4bce-9c3f-c0d427dd6ba5")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="043f9ccc7b181754f67df487ceca659f", element="bbec2f12-c9a2-4dca-8240-956a830b14a4")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="043f9ccc7b181754f67df487ceca659f", element="0568b799-4e27-451e-ba29-c4da9a8adb1a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="043f9ccc7b181754f67df487ceca659f", element="e8f959fd-c24e-408e-a1d6-f4d3f34cedc4")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="043f9ccc7b181754f67df487ceca659f", element="1dc3411d-1102-4243-9bb3-21d3eeaba23a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="043f9ccc7b181754f67df487ceca659f", element="a274f443-694d-4dc6-b246-b6fdb324d241")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="043f9ccc7b181754f67df487ceca659f", element="ec83ba22-23b0-4f08-8baf-cfc7a90dbdef")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="043f9ccc7b181754f67df487ceca659f", element="235900d5-ba6f-4460-9106-81649c4fb98d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="043f9ccc7b181754f67df487ceca659f", element="d3ff19ed-8473-473e-a749-bcf093cdb850")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="043f9ccc7b181754f67df487ceca659f", element="5cd07e2e-4d97-468b-be9b-db3fdc7b3434")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="043f9ccc7b181754f67df487ceca659f", element="ad04236c-5dd9-4bbc-bcec-44eafb1645e0")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="043f9ccc7b181754f67df487ceca659f", element="b43efe84-eccd-43c1-a306-e2e6a72ac7f3")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="043f9ccc7b181754f67df487ceca659f", element="103db6fc-0b07-4618-8105-8990fc161895")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="043f9ccc7b181754f67df487ceca659f", element="76d86c1f-4873-4b1a-8bfb-f5e175424e67")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="043f9ccc7b181754f67df487ceca659f", element="2a2de9a6-8add-450a-839b-8471d88d492a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="043f9ccc7b181754f67df487ceca659f", element="6ca4b2a8-1045-47c6-8782-cfa034027921")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="043f9ccc7b181754f67df487ceca659f", element="37c6351e-261b-4656-a62a-8eec28251bf4")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="043f9ccc7b181754f67df487ceca659f", element="eac10eab-f2b6-4adf-ade4-9b2476accc87")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="043f9ccc7b181754f67df487ceca659f", element="3a141650-33aa-43e6-b961-db64f906f4e2")>]

# %%
for song in songs:
    title = song.find_elements(By.CSS_SELECTOR,'div.ellipsis.rank01 > span > a')[0].text
    singer = song.find_elements(By.CSS_SELECTOR,'div.ellipsis.rank02 > a')[0].text
    print(title, singer, sep = ' | ')
# Out:
# Kitsch | IVE (아이브)
# Ditto | NewJeans
# Hype boy | NewJeans
# OMG | NewJeans
# 꽃 | 지수 (JISOO)
# Nostalgia | 우디 (Woody)
# Teddy Bear | STAYC(스테이씨)
# 사건의 지평선 | 윤하 (YOUNHA)
# I Don't Think That I Like Her | Charlie Puth
# CHRISTIAN | Zior Park
# 파이팅 해야지 (Feat. 이영지) | 부석순 (SEVENTEEN)
# 심(心) | DK(디셈버)
# Attention | NewJeans
# After LIKE | IVE (아이브)
# 사랑하기 싫어 | 지아
# ANTIFRAGILE | LE SSERAFIM (르세라핌)
# 밤이 무서워요 (Lonely Night) | 주주 시크릿
# Love Me Like This | NMIXX
# LOVE DIVE | IVE (아이브)
# 사랑인가 봐 | 멜로망스
# 벚꽃 엔딩 | 버스커 버스커
# NIGHT DANCER | imase
# Like Crazy | 지민
# 나비무덤 | 포맨 (4MEN)
# 너를 보는게 지친 하루에 | 송하예
# Dangerously | Charlie Puth
# 봄 사랑 벚꽃 말고 | HIGH4 (하이포)
# 사랑은 늘 도망가 | 임영웅
# 결국엔 너에게 닿아서 | WSG워너비 (가야G)
# Candy | NCT DREAM
# 건물 사이에 피어난 장미 (Rose Blossom) | H1-KEY (하이키)
# VIBE (feat. Jimin of BTS) | 태양
# 너의 모든 순간 | 성시경
# Nxde | (여자)아이들
# Expectations | Anne-Marie
# Say I Love You | 우디 (Woody)
# Monologue | 테이
# That's Hilarious | Charlie Puth
# 새삥 (Prod. ZICO) (Feat. 호미들) | 지코 (ZICO)
# 해요 (2022) | #안녕
# Cookie | NewJeans
# 우연히 봄 | 로꼬
# 취중고백 | 김민석 (멜로망스)
# on the street (with J. Cole) | j-hope
# STAY | The Kid LAROI
# 그라데이션 | 10CM
# Shut Down | BLACKPINK
# 내가 아니라도 | 주호
# TOMBOY | (여자)아이들
# 정이라고 하자 (Feat. 10CM) | BIG Naughty (서동현)
