# %% [markdown]
# ## 웹 스크래핑

# %% [markdown]
# ### 정규표현식

# %% [markdown]
# * HTML Parsing
# * 웹 페이지의 HTML을 분석하여 필요한 URL을 추출하는 HTML파싱 작업이 필요
# * 파싱은 특정 텍스트를 분석하여 그 데이터로부터 필요한 정보를 추출하는 과정

# %%
# 필요 패키지 불러오기
import urllib.request

# 정규 표현식 모듈
import re

# %%
# 삼성전자 주식정보 파싱
url = "https://finance.naver.com/item/main.nhn?code=005930"
html = urllib.request.urlopen(url)
html_contents = str(html.read().decode('ms949'))

# %%
html_contents
# Out:
# '\n\n\t\n\t\n\t\n\t\n<html lang=\'ko\'>\n<head>\n\n\n\t\n\t\t<title>삼성전자 : 네이버 증권</title>\n\t\n\t\n\n\n\n\n\n\t\n\t\n\t\t<meta http-equiv="Content-Type" content="text/html; charset=utf-8" />\n\t\n\n\n<meta http-equiv="Content-Script-Type" content="text/javascript">\n<meta http-equiv="Content-Style-Type" content="text/css">\n<meta name="apple-mobile-web-app-title" content="네이버 증권" />\n\n\n\n\n\n\t\n    \n        <meta property="og:url" content="https://finance.naver.com/item/main.naver?code=005930"/>\n        \n\t\t\t\n\t\t    \n\t\t    \t<meta property="og:title" content="삼성전자 - 네이버 증권 : 네이버 증권"/>\n\t\t     \n\t\t\n\t\t\n\t\t\t\n\t\t\t   <meta property="og:description" content="관심종목의 실시간 주가를 가장 빠르게 확인하는 곳"/>\n\t\t    \n\t\t    \n\t\t\n\t\t \n\t\t\t\n\t\t\t    <meta property="og:image" content="https://ssl.pstatic.net/static/m/stock/im/2016/08/og_stock-200.png"/>\n\t\t    \n\t\t    \n\t\t\n    \n\n<meta property="og:type" content="article"/>\n<meta property="og:article:thumbnailUrl" content=""/>\n<meta property="og:article:author" content="네이버 증권"/>\n<meta property="og:article:author:url" content="http://FINANCE.NAVER.COM"/>\n\n\n\n\n\n\n<link rel=\'stylesheet\' type=\'text/css\' href=\'https://ssl.pstatic.net/imgstock/static.pc/20230321170048/css/finance_header.css\'>\n\n\t\n\t\n\t\n\t\n\t\t\n\t\t<link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/imgstock/static.pc/20230321170048/css/newstock.css">\n\t\t<link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/imgstock/static.pc/20230321170048/css/common.css">\n\t\t<link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/imgstock/static.pc/20230321170048/css/layout.css">\n\t\t<link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/imgstock/static.pc/20230321170048/css/main.css">\n\t\t<link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/imgstock/static.pc/20230321170048/css/newstock2.css">\n\t\t<link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/imgstock/static.pc/20230321170048/css/newstock3.css">\n\t\t<link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/imgstock/static.pc/20230321170048/css/world.css">\n\t\t\n\t\t\t\n\t\t\t\n\t\t\t\t<script type="text/javascript" src="https://ssl.pstatic.net/imgstock/static.pc/20230321170048/js/jindo.min.ns.1.5.3.euckr.js"></script>\n\t\t\t\t<script type="text/javascript" src="https://ssl.pstatic.net/imgstock/static.pc/20230321170048/js/release/common.js"></script>\n\t\t\t\t<script type="text/javascript" src="https://ssl.pstatic.net/imgstock/static.pc/20230321170048/js/jindoComponent/jindo.Component.1.0.3.js"></script>\n\t\t\t\t<script type="text/javascript" src="https://ssl.pstatic.net/imgstock/static.pc/20230321170048/js/nhn.autocomplete.stock.js"></script>\n\t\t\t\n\t\t\n\n\t\t\n\t\n\n<script>\n\tvar ieVersion = (function () {\n        var version = -1;\n        if (\n          navigator.appName == \'Microsoft Internet Explorer\' &&\n          navigator.userAgent.toLowerCase().indexOf(\'msie\') != -1 &&\n          new RegExp(\'MSIE ([0-9]{1,}[\\./0-9]{0,})\').exec(navigator.userAgent) != null\n        ) {\n          version = parseInt(RegExp.$1);\n        }\n        return version;\n      })();\n</script>\n\t\n\t<!-- smart channel 광고 -->\n\t<script async src="https://ssl.pstatic.net/tveta/libs/glad/prod/gfp-core.js">\n\t\t</script>\n\t<script type="text/javascript">\n\t\t(function(){\n\t\t\tif (ieVersion === -1 || ieVersion > 10) {\n\t\t\t\twindow.gladsdk = window.gladsdk || { cmd: [] };\n\n\t\t\t\tgladsdk.cmd.push(function() {\n\t\t\t\t\t\tgladsdk.defineAdSlot({\n\t\t\t\t\t\t\tadUnitId: "p_nf_stock",\n\t\t\t\t\t\t\tadSlotElementId: "_SmartChannelTopBanner",\n\t\t\t\t\t\t\tuct: "KR",\n\t\t\t\t\t\t\tcustomParam: {\n\t\t\t\t\t\t\t\tcalp: \n\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t"home"\n\t\t\t\t\t\t\t},\n\t\t\t\t\t\t});\n\n\n\n\t\t\t\t\t\tglads ...

# %%
# 첫번째 HTML 패턴
stock_results = re.findall('(\<dl class=\"blind\")([\s\S]+?)(\</dl\>)', html_contents)

# 튜플의 형태로 리턴
stock_results
# Out:
# [('<dl class="blind"',
#   '>\n\t        <dt>종목 시세 정보</dt>\n\t        <dd>2023년 04월 03일 16시 11분 기준 장마감</dd>\n\t        <dd>종목명 삼성전자</dd>\n\t        <dd>종목코드 005930 코스피</dd>\n\t        <dd>현재가 63,100 전일대비 하락 900 마이너스 1.41 퍼센트</dd>\n\t        <dd>전일가 64,000</dd>\n\t        <dd>시가 64,000</dd>\n\t        <dd>고가 64,000</dd>\n\t        <dd>상한가 83,200</dd>\n\t        <dd>저가 63,000</dd>\n\t        <dd>하한가 44,800</dd>\n\t        <dd>거래량 11,941,193</dd>\n\t        <dd>거래대금 755,268백만</dd>\n        ',
#   '</dl>'),
#  ('<dl class="blind"',
#   '>\n                        <dt><strong>삼성전자</strong></dt>\n                        <dd>오늘의시세 63,100 포인트</dd>\n                        <dd>900 포인트 하락</dd>\n                        <dd>1.41% 마이너스</dd>\n                ',
#   '</dl>')]

# %%
# 두 개의 튜플 값중 첫번째 패턴
samsung_stock = stock_results[0]
samsung_stock
# Out:
# ('<dl class="blind"',
#  '>\n\t        <dt>종목 시세 정보</dt>\n\t        <dd>2023년 04월 03일 16시 11분 기준 장마감</dd>\n\t        <dd>종목명 삼성전자</dd>\n\t        <dd>종목코드 005930 코스피</dd>\n\t        <dd>현재가 63,100 전일대비 하락 900 마이너스 1.41 퍼센트</dd>\n\t        <dd>전일가 64,000</dd>\n\t        <dd>시가 64,000</dd>\n\t        <dd>고가 64,000</dd>\n\t        <dd>상한가 83,200</dd>\n\t        <dd>저가 63,000</dd>\n\t        <dd>하한가 44,800</dd>\n\t        <dd>거래량 11,941,193</dd>\n\t        <dd>거래대금 755,268백만</dd>\n        ',
#  '</dl>')

# %%
# 세 개의 튜플 값중 두번째 패턴
samsung_index = samsung_stock[1]
samsung_index
# Out:
# '>\n\t        <dt>종목 시세 정보</dt>\n\t        <dd>2023년 04월 03일 16시 11분 기준 장마감</dd>\n\t        <dd>종목명 삼성전자</dd>\n\t        <dd>종목코드 005930 코스피</dd>\n\t        <dd>현재가 63,100 전일대비 하락 900 마이너스 1.41 퍼센트</dd>\n\t        <dd>전일가 64,000</dd>\n\t        <dd>시가 64,000</dd>\n\t        <dd>고가 64,000</dd>\n\t        <dd>상한가 83,200</dd>\n\t        <dd>저가 63,000</dd>\n\t        <dd>하한가 44,800</dd>\n\t        <dd>거래량 11,941,193</dd>\n\t        <dd>거래대금 755,268백만</dd>\n        '

# %%
# 주식 정보만 추출
index_list = re.findall("(\<dd\>)([\s\S]+?)(\</dd\>)", samsung_index)
index_list
# Out:
# [('<dd>', '2023년 04월 03일 16시 11분 기준 장마감', '</dd>'),
#  ('<dd>', '종목명 삼성전자', '</dd>'),
#  ('<dd>', '종목코드 005930 코스피', '</dd>'),
#  ('<dd>', '현재가 63,100 전일대비 하락 900 마이너스 1.41 퍼센트', '</dd>'),
#  ('<dd>', '전일가 64,000', '</dd>'),
#  ('<dd>', '시가 64,000', '</dd>'),
#  ('<dd>', '고가 64,000', '</dd>'),
#  ('<dd>', '상한가 83,200', '</dd>'),
#  ('<dd>', '저가 63,000', '</dd>'),
#  ('<dd>', '하한가 44,800', '</dd>'),
#  ('<dd>', '거래량 11,941,193', '</dd>'),
#  ('<dd>', '거래대금 755,268백만', '</dd>')]

# %%
# 세 개의 튜플 값중 두번째 값
for index in index_list:
    print(index[1])
# Out:
# 2023년 04월 03일 16시 11분 기준 장마감
# 종목명 삼성전자
# 종목코드 005930 코스피
# 현재가 63,100 전일대비 하락 900 마이너스 1.41 퍼센트
# 전일가 64,000
# 시가 64,000
# 고가 64,000
# 상한가 83,200
# 저가 63,000
# 하한가 44,800
# 거래량 11,941,193
# 거래대금 755,268백만

# %%
# 애플 주식정보 파싱

# %% [markdown]
# ## 웹 크롤링

# %% [markdown]
# * 웹 페이지에 있는 정보를 가지고 오는 것을 의미
# * selenium 라이브러리의 webdriver를 활용해 웹 브라우저 조작
# * BeautifulSoup라이브러리를 활용해 웹 페이지 상의 HTML데이터에서 필요한 정보를 가져 옴

# %%
# 필요  패키지 불러오기
# !pip install selenium
# Out:
# Requirement already satisfied: selenium in c:\anaconda3\envs\pythonex\lib\site-packages (4.8.3)
# Requirement already satisfied: trio~=0.17 in c:\anaconda3\envs\pythonex\lib\site-packages (from selenium) (0.22.0)
# Requirement already satisfied: certifi>=2021.10.8 in c:\anaconda3\envs\pythonex\lib\site-packages (from selenium) (2022.12.7)
# Requirement already satisfied: trio-websocket~=0.9 in c:\anaconda3\envs\pythonex\lib\site-packages (from selenium) (0.10.2)
# Requirement already satisfied: urllib3[socks]~=1.26 in c:\anaconda3\envs\pythonex\lib\site-packages (from selenium) (1.26.14)
# Requirement already satisfied: sniffio in c:\anaconda3\envs\pythonex\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: attrs>=19.2.0 in c:\anaconda3\envs\pythonex\lib\site-packages (from trio~=0.17->selenium) (22.1.0)
# Requirement already satisfied: idna in c:\anaconda3\envs\pythonex\lib\site-packages (from trio~=0.17->selenium) (3.4)
# Requirement already satisfied: sortedcontainers in c:\anaconda3\envs\pythonex\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: exceptiongroup>=1.0.0rc9 in c:\anaconda3\envs\pythonex\lib\site-packages (from trio~=0.17->selenium) (1.1.1)
# Requirement already satisfied: cffi>=1.14 in c:\anaconda3\envs\pythonex\lib\site-packages (from trio~=0.17->selenium) (1.15.1)
# Requirement already satisfied: async-generator>=1.9 in c:\anaconda3\envs\pythonex\lib\site-packages (from trio~=0.17->selenium) (1.10)
# Requirement already satisfied: outcome in c:\anaconda3\envs\pythonex\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: wsproto>=0.14 in c:\anaconda3\envs\pythonex\lib\site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in c:\anaconda3\envs\pythonex\lib\site-packages (from urllib3[socks]~=1.26->selenium) (1.7.1)
# Requirement already satisfied: pycparser in c:\anaconda3\envs\pythonex\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\anaconda3\envs\pythonex\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)

# %%
from selenium import webdriver

# %%
# 크롬 드라이버 활용
# 크롬 드라이버 경로가 정확히 등록되어야 함
driver = webdriver.Chrome('D:/chromedriver/chromedriver.exe')
# Out:
# C:\Users\chunc\AppData\Local\Temp\ipykernel_44636\706859011.py:3: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('D:/chromedriver/chromedriver.exe')

# %%
# URL접속
url = 'http://www.naver.com'
driver.get(url)

# 웹 페이지 HTML 다운로드
html = driver.page_source
html
# Out:
# '<html lang="ko" data-dark="false" data-useragent="Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/111.0.0.0 Safari/537.36"><head><script async="" type="text/javascript" src="https://ssl.pstatic.net/tveta/libs/ndpsdk/prod/ndp-core.js"></script> <meta charset="utf-8"> <title>NAVER</title> <meta http-equiv="X-UA-Compatible" content="IE=edge"> <meta name="viewport" content="width=1190"> <meta name="apple-mobile-web-app-title" content="NAVER"> <meta name="robots" content="index,nofollow"> <meta name="description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"> <meta property="og:title" content="네이버"> <meta property="og:url" content="https://www.naver.com/"> <meta property="og:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta property="og:description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"> <meta name="twitter:card" content="summary"> <meta name="twitter:title" content=""> <meta name="twitter:url" content="https://www.naver.com/"> <meta name="twitter:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta name="twitter:description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요">  <link rel="stylesheet" href="https://pm.pstatic.net/dist/css/nmain.20230302.css"> <link rel="stylesheet" href="https://ssl.pstatic.net/sstatic/search/pc/css/sp_autocomplete_220526.css"> <link rel="shortcut icon" type="image/x-icon" href="/favicon.ico?1">  <link rel="apple-touch-icon" sizes="114x114" href="https://s.pstatic.net/static/www/u/2014/0328/mma_204243574.png"> <link rel="apple-touch-icon" href="https://s.pstatic.net/static/www/u/2014/0328/mma_20432863.png"> <script>window.nmain=window.nmain||{},window.nmain.supportFlicking=!1;var nsc="navertop.v4",ua=navigator.userAgent,useIeJSFlag="1";window.nmain.isIE="0"===useIeJSFlag,document.getElementsByTagName("html")[0].setAttribute("data-useragent",ua),window.nmain.isIE&&(Object.create=function(n){function e(){}return e.prototype=n,new e})</script> <script>var darkmode= false;window.naver_corp_da=window.naver_corp_da||{main:{}},window.naver_corp_da.main=window.naver_corp_da.main||{},window.naver_corp_da.main.darkmode=darkmode,window.gladsdk=window.gladsdk||{cmd:[]},window.gladsdk.cmd.push((function(){window.gladsdk.setHostMeta("theme",darkmode?"dark":"light")})),window.ndpsdk=window.ndpsdk||{cmd:[],polyfill:{cmd:[]}},window.ndpsdk.cmd.push((function(){window.ndpsdk.setHostMeta("theme",darkmode?"dark":"light")}))</script>  <script async="" src="https://ssl.pstatic.net/tveta/libs/glad/prod/gfp-core.js"></script> <script async="" src="https://ssl.pstatic.net/tveta/libs/ndpsdk/prod/ndp-loader.js"></script>  <script> window.nmain.gv = {  isLogin: false,\nuseId: null,   daInfo: {"BEAUTY":{"menu":"BEAUTY","childMenu":"","adType":"singleDom","multiDomAdUrl":"","multiDomUnit":"","infoList":[{"adposId":"1000163","singleDomAdUrl":"https://siape.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_beauty_1","tb":"BEAUTY_1","unit":"SU10595","calp":"-"},"type":{"position":"abs","positionIndex":4,"subject":"contents"},"dom":null},{"adposId":"1000164","singleDomAdUrl":"https://siape.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_beauty_2","tb":"BEAUTY_1","unit":"SU10596","calp":"-"},"type":{"position":"abs","positionIndex":8,"subject":"contents"},"dom":null}]},"LIVING":{"menu":"LIVING","childMenu":"","adType":"singleDom","multiDomAdUrl":"","multiDomUnit":"","infoList":[{"adposId":"1000183","singleDomAdUrl":"https://siape.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_living_1","tb":"LIVING_1","unit":"SU10597","calp":"-"},"type":{"position":"abs","positionIndex":4,"subject":"contents"},"dom":null},{"adposId":"1000184","singleDomAdUrl":"https://siape.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_living_2","tb":"LIVING_1","unit":"SU10606","calp":"-"},"type":{"position":"abs","positionIndex":8,"subject":"contents"},"dom":null}]},"LIVINGHOME":{"menu":"LIVINGHOME","childMenu":"" ...

# %% [markdown]
# ### 크롤링 연습(멜론차트)

# %%
# 필요패키지 설치
# !pip install beautifulsoup4
# Out:
# Requirement already satisfied: beautifulsoup4 in c:\anaconda3\envs\pythonex\lib\site-packages (4.11.1)
# Requirement already satisfied: soupsieve>1.2 in c:\anaconda3\envs\pythonex\lib\site-packages (from beautifulsoup4) (2.3.2.post1)

# %%
# 크롤링 연습(멜론)
from selenium import webdriver
driver = webdriver.Chrome('D:/chromedriver/chromedriver.exe')
url = 'https://www.melon.com/chart/day/index.htm'
driver.get(url)
# Out:
# C:\Users\chunc\AppData\Local\Temp\ipykernel_44636\2861460903.py:3: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('D:/chromedriver/chromedriver.exe')

# %%
# BeautifulSoup패키지 모듈을 사용 멜론 일간 차트 파싱
from bs4 import BeautifulSoup
html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')

# %%
# 일간차트 1~50위 항목을 불러오기
songs = soup.select('#lst50')
# print(len(songs))
print(songs[0])
# Out:
# <tr class="lst50" data-song-no="36318125" id="lst50">
# <td><div class="wrap t_right"><input class="input_check" name="input_check" title="Kitsch 곡 선택" type="checkbox" value="36318125"/></div></td>
# <td><div class="wrap t_center"><span class="rank">1</span><span class="none">위</span></div></td>
# <!-- 차트순위 추가 -->
# <td><div class="wrap">
# <span class="rank_wrap" title="순위 동일">
# <span class="bullet_icons rank_static"><span class="none">순위 동일</span></span>
# <span class="none">0</span>
# </span>
# </div></td>
# <td><div class="wrap">
# <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('11211297');" title="Kitsch">
# <img alt="Kitsch - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="https://cdnimg.melon.co.kr/cm2/album/images/112/11/297/11211297_20230327114349_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
# <span class="bg_album_frame"></span>
# </a>
# </div></td>
# <td><div class="wrap">
# <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('36318125');" title="Kitsch 곡정보"><span class="none">곡정보</span></a>
# </div></td>
# <td><div class="wrap">
# <div class="wrap_song_info">
# <div class="ellipsis rank01"><span>
# <a href="javascript:melon.play.playSong('19041201',36318125);" title="Kitsch 재생">Kitsch</a>
# </span></div><br/>
# <div class="ellipsis rank02">
# <a href="javascript:melon.link.goArtistDetail('3055146');" title="IVE (아이브) - 페이지 이동">IVE (아이브)</a><span class="checkEllipsis" style="display: none;"><a href="javascript:melon.link.goArtistDetail('3055146');" title="IVE (아이브) - 페이지 이동">IVE (아이브)</a></span>
# </div>
# </div>
# </div></td>
# <td><div class="wrap">
# <div class="wrap_song_info">
# <div class="ellipsis rank03">
# <a href="javascript:melon.link.goAlbumDetail('11211297');" title="Kitsch - 페이지 이동">Kitsch</a>
# </div>
# </div>
# </div></td>
# <td><div class="wrap">
# <button class="button_etc like" data-song-menuid="19041201" data-song-no="36318125" title="Kitsch 좋아요" type="button"><span class="odd_span">좋아요</span>
# <span class="cnt">
# <span class="none">총건수</span>
# 57,679</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons play" onclick="melon.play.playSong('19041201',36318125);" title="듣기" type="button"><span class="none">듣기</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons scrap" onclick="melon.play.addPlayList('36318125');" title="담기" type="button"><span class="none">담기</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons download" onclick="melon.buy.goBuyProduct('frm', '36318125', '3C0001', '','0', '19041201');" title="다운로드" type="button"><span class="none">다운로드</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons video" onclick="melon.link.goMvDetail('19041201', '36318125','song');" title="뮤직비디오" type="button"><span class="none">뮤직비디오</span></button>
# </div></td>
# </tr>

# %%
# 일간차트 1위곡의 제목 추출
title = soup.select('div.ellipsis.rank01 > span > a')[0].text
title
# Out:
# 'Kitsch'

# %%
singer = soup.select('div.ellipsis.rank02 > a')[0].text
singer
# Out:
# 'IVE (아이브)'

# %%
# for문을 사용하여 차트50위까지의 곡들의 제목과 가수 출력
for song in songs:
    title = song.select('div.ellipsis.rank01 > span > a')[0].text
    singer = song.select('div.ellipsis.rank02 > a')[0].text
    print(title, singer, sep = '  |  ')
# Out:
# Kitsch  |  IVE (아이브)
# Ditto  |  NewJeans
# Hype boy  |  NewJeans
# OMG  |  NewJeans
# 꽃  |  지수 (JISOO)
# Nostalgia  |  우디 (Woody)
# Teddy Bear  |  STAYC(스테이씨)
# 사건의 지평선  |  윤하 (YOUNHA)
# I Don't Think That I Like Her  |  Charlie Puth
# CHRISTIAN  |  Zior Park
# 파이팅 해야지 (Feat. 이영지)  |  부석순 (SEVENTEEN)
# 심(心)  |  DK(디셈버)
# Attention  |  NewJeans
# After LIKE  |  IVE (아이브)
# 사랑하기 싫어  |  지아
# ANTIFRAGILE  |  LE SSERAFIM (르세라핌)
# 밤이 무서워요 (Lonely Night)  |  주주 시크릿
# Love Me Like This  |  NMIXX
# LOVE DIVE  |  IVE (아이브)
# 사랑인가 봐  |  멜로망스
# 벚꽃 엔딩  |  버스커 버스커
# NIGHT DANCER  |  imase
# Like Crazy  |  지민
# 나비무덤  |  포맨 (4MEN)
# 너를 보는게 지친 하루에  |  송하예
# Dangerously  |  Charlie Puth
# 봄 사랑 벚꽃 말고  |  HIGH4 (하이포)
# 사랑은 늘 도망가  |  임영웅
# 결국엔 너에게 닿아서  |  WSG워너비 (가야G)
# Candy  |  NCT DREAM
# 건물 사이에 피어난 장미 (Rose Blossom)  |  H1-KEY (하이키)
# VIBE (feat. Jimin of BTS)  |  태양
# 너의 모든 순간  |  성시경
# Nxde  |  (여자)아이들
# Expectations  |  Anne-Marie
# Say I Love You  |  우디 (Woody)
# Monologue  |  테이
# That's Hilarious  |  Charlie Puth
# 새삥 (Prod. ZICO) (Feat. 호미들)  |  지코 (ZICO)
# 해요 (2022)  |  #안녕
# Cookie  |  NewJeans
# 우연히 봄  |  로꼬
# 취중고백  |  김민석 (멜로망스)
# on the street (with J. Cole)  |  j-hope
# STAY  |  The Kid LAROI
# 그라데이션  |  10CM
# Shut Down  |  BLACKPINK
# 내가 아니라도  |  주호
# TOMBOY  |  (여자)아이들
# 정이라고 하자 (Feat. 10CM)  |  BIG Naughty (서동현)

# %%
# 51~100위 차트 불러오기
songs = soup.select('#lst100')
print(songs[0])
# Out:
# <tr class="lst100" data-song-no="36266614" id="lst100" style="">
# <td><div class="wrap t_right"><input class="input_check" name="input_check" title="Young, Dumb, Stupid 곡 선택" type="checkbox" value="36266614"/></div></td>
# <td><div class="wrap t_center"><span class="rank">51</span><span class="none">위</span></div></td>
# <!-- 차트순위 추가 -->
# <td><div class="wrap">
# <span class="rank_wrap" title="18단계 상승">
# <span class="bullet_icons rank_up"><span class="none">단계 상승</span></span>
# <span class="up">18</span>
# </span>
# </div></td>
# <td><div class="wrap">
# <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('11201031');" title="expérgo">
# <img alt="expérgo - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="https://cdnimg.melon.co.kr/cm2/album/images/112/01/031/11201031_20230320162256_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
# <span class="bg_album_frame"></span>
# </a>
# </div></td>
# <td><div class="wrap">
# <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('36266614');" title="Young, Dumb, Stupid 곡정보"><span class="none">곡정보</span></a>
# </div></td>
# <td><div class="wrap">
# <div class="wrap_song_info">
# <div class="ellipsis rank01"><span>
# <a href="javascript:melon.play.playSong('19041201',36266614);" title="Young, Dumb, Stupid 재생">Young, Dumb, Stupid</a>
# </span></div><br/>
# <div class="ellipsis rank02">
# <a href="javascript:melon.link.goArtistDetail('3070786');" title="NMIXX - 페이지 이동">NMIXX</a><span class="checkEllipsis" style="display: none;"><a href="javascript:melon.link.goArtistDetail('3070786');" title="NMIXX - 페이지 이동">NMIXX</a></span>
# </div>
# </div>
# </div></td>
# <td><div class="wrap">
# <div class="wrap_song_info">
# <div class="ellipsis rank03">
# <a href="javascript:melon.link.goAlbumDetail('11201031');" title="expérgo - 페이지 이동">expérgo</a>
# </div>
# </div>
# </div></td>
# <td><div class="wrap">
# <button class="button_etc like" data-song-menuid="19041201" data-song-no="36266614" title="Young, Dumb, Stupid 좋아요" type="button"><span class="odd_span">좋아요</span>
# <span class="cnt">
# <span class="none">총건수</span>
# 20,265</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons play" onclick="melon.play.playSong('19041201',36266614);" title="듣기" type="button"><span class="none">듣기</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons scrap" onclick="melon.play.addPlayList('36266614');" title="담기" type="button"><span class="none">담기</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons download" onclick="melon.buy.goBuyProduct('frm', '36266614', '3C0001', '','0', '19041201');" title="다운로드" type="button"><span class="none">다운로드</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons video" onclick="melon.link.goMvDetail('19041201', '36266614','song');" title="뮤직비디오" type="button"><span class="none">뮤직비디오</span></button>
# </div></td>
# </tr>

# %%
for song in songs:
    title = song.select('div.ellipsis.rank01 > span > a')[0].text
    singer = song.select('div.ellipsis.rank02 > a')[0].text
    print(title, singer, sep = '  |  ')
# Out:
# Young, Dumb, Stupid  |  NMIXX
# 그때 그 순간 그대로 (그그그)  |  WSG워너비 (가야G)
# Unholy  |  Sam Smith
# 다정히 내 이름을 부르면  |  경서예지
# Pink Venom  |  BLACKPINK
# 봄날  |  방탄소년단
# 되돌리다  |  먼데이 키즈 (Monday Kiz)
# Set Me Free Pt.2  |  지민
# FEARLESS  |  LE SSERAFIM (르세라핌)
# 우리들의 블루스  |  임영웅
# 오르트구름  |  윤하 (YOUNHA)
# Dynamite  |  방탄소년단
# NOT SORRY (Feat. pH-1) (Prod. by Slom)  |  이영지
# ELEVEN  |  IVE (아이브)
# Poppy (Korean Ver.)  |  STAYC(스테이씨)
# 사랑이라 믿었던 것들은 (Feat. 이수현)  |  BIG Naughty (서동현)
# 나의 X에게  |  경서
# Rush Hour (Feat. j-hope of BTS)  |  Crush
# 나만, 봄  |  볼빨간사춘기
# 모든 날, 모든 순간 (Every day, Every Moment)  |  폴킴
# 그대를 알고  |  송하예
# 혼자가 아닌 나  |  정효빈
# 딱 10CM만  |  10CM
# 잘가요  |  주호
# 아모르 파티  |  이홍기 (FT아일랜드)
# That That (prod. & feat. SUGA of BTS)  |  싸이 (PSY)
# Sugar Rush Ride  |  투모로우바이투게더
# Off My Face  |  Justin Bieber
# 그대라는 사치  |  임창정
# Dreamers [Music from the FIFA World Cup Qatar 2022 Official Soundtrack] (Feat. FIFA Sound)  |  정국
# 너와 함께  |  김민석 (멜로망스)
# 다시 만날 수 있을까  |  임영웅
# Butter  |  방탄소년단
# 마지막 사랑  |  신예영
# London Boy  |  임영웅
# 이제 나만 믿어요  |  임영웅
# 그댄 행복에 살텐데 (2022)  |  최유리
# 자격지심 (Feat. ZICO)  |  BE'O (비오)
# LOVE me  |  BE'O (비오)
# Polaroid  |  임영웅
# 봄이 좋냐??  |  10CM
# 봄여름가을겨울 (Still Life)  |  BIGBANG (빅뱅)
# 네가 보고 싶은 건 자연스러운 거겠지  |  신예영
# 밤하늘의 별을(2020)  |  경서
# All Eyes On Me  |  지수 (JISOO)
# Permission to Dance  |  방탄소년단
# Love story  |  볼빨간사춘기
# 흔들리는 꽃들 속에서 네 샴푸향이 느껴진거야  |  장범준
# 무지개  |  임영웅
# 내 기쁨은 너가 벤틀리를 끄는 거야  |  김승민

# %%
# selenium만을 활용한 크롤링 연습
# 모듈이 계속 업데이트가 되므로 함수명이 변경될 수도 있다
from selenium.webdriver.common.by import By
driver = webdriver.Chrome('D:/chromedriver/chromedriver.exe')
url = 'https://www.melon.com/chart/day/index.htm'
driver.get(url)
# Out:
# C:\Users\chunc\AppData\Local\Temp\ipykernel_44636\2337218689.py:4: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('D:/chromedriver/chromedriver.exe')

# %%
songs = driver.find_elements(By.CSS_SELECTOR, '#lst50')
songs
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="24bc4a8538758711ca1e5fb15321c864", element="d697f146-7c5e-4060-a754-6f88c38f7159")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="24bc4a8538758711ca1e5fb15321c864", element="07c2f8e2-bf2b-4a9b-8284-d04fcc093a49")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="24bc4a8538758711ca1e5fb15321c864", element="214ae559-9894-4a47-8a44-a45edf3f39bf")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="24bc4a8538758711ca1e5fb15321c864", element="ba8f583f-f9ce-49c6-85f7-4b6f0068570e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="24bc4a8538758711ca1e5fb15321c864", element="c6698af5-b4da-47ed-8a43-1652f7fe620d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="24bc4a8538758711ca1e5fb15321c864", element="6f988a39-b429-4224-9ced-3411aabeb197")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="24bc4a8538758711ca1e5fb15321c864", element="1c8fda26-d601-4f15-92bd-c90f662e844c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="24bc4a8538758711ca1e5fb15321c864", element="1ef2bc4d-aced-475e-a6c2-6abfc14eafb7")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="24bc4a8538758711ca1e5fb15321c864", element="81b408d4-7ee1-4b2c-86a1-dc5833d99771")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="24bc4a8538758711ca1e5fb15321c864", element="e78c66ee-c950-45bd-bc70-31c04414fa08")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="24bc4a8538758711ca1e5fb15321c864", element="e7c35e26-c895-4c2c-8fdd-85d0d338a195")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="24bc4a8538758711ca1e5fb15321c864", element="793212aa-955e-4cdd-b223-9fdfc8b7d760")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="24bc4a8538758711ca1e5fb15321c864", element="2f0d6b77-8ac3-457c-9a37-4398f800b61d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="24bc4a8538758711ca1e5fb15321c864", element="920a6573-5c2b-4435-88cb-9e1f40aab1c9")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="24bc4a8538758711ca1e5fb15321c864", element="d216c1df-be34-4524-baca-fc07b6a38fae")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="24bc4a8538758711ca1e5fb15321c864", element="6487772a-2f79-4a92-b1fe-1841e371c1fd")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="24bc4a8538758711ca1e5fb15321c864", element="f5eeece2-23d0-46dc-ac18-e5ec02d689fc")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="24bc4a8538758711ca1e5fb15321c864", element="a2f4afb9-e33a-4d4c-9104-5cb5281b3b89")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="24bc4a8538758711ca1e5fb15321c864", element="f643b13d-f4be-4121-b13d-81a6f4380aff")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="24bc4a8538758711ca1e5fb15321c864", element="01573b13-0ab7-47d1-a499-dd1aa5c51b70")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="24bc4a8538758711ca1e5fb15321c864", element="32b4db8f-31f2-4c33-95a5-5e13320d79a8")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="24bc4a8538758711ca1e5fb15321c864", element="4fb05013-5b7d-4c4f-a213-bfbb0e0ccf35")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="24bc4a8538758711ca1e5fb15321c864", element="6229c6cb-ece3-4f62-bfdc-fca2d56ba426")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="24bc4a8538758711ca1e5fb15321c864", element="342c7048-8fd9-418d-b15d-5f05a4bbc419")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="24bc4a8538758711ca1e5fb15321c864", element="f0a84a9d-f8af-46f7-8c99-5b64ccfa5edb")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="24bc4a8538758711ca1e5fb15321c864", element="adbf4419-011c-49a4-8819-5951cfa39a49")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="24bc4a8538758711ca1e5fb15321c864", element="1719f207-290b-49a9-a393-22dc6d2a367c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="24bc4a8538758711ca1e5fb15321c864", element="c049449b-2805-4193-9b37-6ec6f87324b3")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="24bc4a8538758711ca1e5fb15321c864", element="3447b624-0346-4c69-baef-30ba39cbb703")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="24bc4a8538758711ca1e5fb15321c864", element="0d8c4cc0-0440-46d2-a0b2-6ef8778398aa")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="24bc4a8538758711ca1e5fb15321c864", element="907278a0-be32-4843-b413-891aaf8beae8")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="24bc4a8538758711ca1e5fb15321c864", element="9f78877f-8b7e-4b69-ad4a-81923e6296b6")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="24bc4a8538758711ca1e5fb15321c864", element="d0c0b5d9-33e3-427a-a353-4297e1e7edcf")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="24bc4a8538758711ca1e5fb15321c864", element="0cc87a46-7afd-4815-90c0-b91004963ab8")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="24bc4a8538758711ca1e5fb15321c864", element="b202e290-5356-475d-81bf-d3615b8d6d80")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="24bc4a8538758711ca1e5fb15321c864", element="a7f526cc-fae5-4683-9003-d67abe474d79")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="24bc4a8538758711ca1e5fb15321c864", element="d9156ff4-d849-4978-a515-853524220b17")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="24bc4a8538758711ca1e5fb15321c864", element="e667c035-7d40-407a-8c7d-69977f5d22cc")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="24bc4a8538758711ca1e5fb15321c864", element="c435a868-04f1-4de5-b159-a48fa257a733")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="24bc4a8538758711ca1e5fb15321c864", element="f888721f-e33e-4a7b-965f-8454c32d3245")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="24bc4a8538758711ca1e5fb15321c864", element="e7fd947a-e3f0-4565-ac19-5e2cf261238b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="24bc4a8538758711ca1e5fb15321c864", element="8b7d986d-9733-475f-b9f7-45da0487927d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="24bc4a8538758711ca1e5fb15321c864", element="95027bd6-2727-40dc-9e97-0bcf0a86b3a3")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="24bc4a8538758711ca1e5fb15321c864", element="c2548939-c6d2-4a99-ab19-0215668e1f89")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="24bc4a8538758711ca1e5fb15321c864", element="0321166b-6194-4e46-b30a-7addac44a8ad")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="24bc4a8538758711ca1e5fb15321c864", element="ab0fbc78-ab44-4893-b13f-ba22d7ec75f5")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="24bc4a8538758711ca1e5fb15321c864", element="4bf5a5ad-9344-4030-8fd8-9132b5ebeadb")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="24bc4a8538758711ca1e5fb15321c864", element="ec4659e3-2117-426e-96d4-781a1327f9b4")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="24bc4a8538758711ca1e5fb15321c864", element="fb722f70-636d-4e2a-8426-3113b54c879b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="24bc4a8538758711ca1e5fb15321c864", element="f5e992e5-6b3a-4632-b4cf-988d871f60ab")>]

# %%
for song in songs:
    title = song.find_elements(By.CSS_SELECTOR,'div.ellipsis.rank01 > span > a')[0].text
    singer = song.find_elements(By.CSS_SELECTOR,'div.ellipsis.rank02 > a')[0].text
    print(title, singer, sep = ' | ')
# Out:
# Kitsch | IVE (아이브)
# Ditto | NewJeans
# Hype boy | NewJeans
# OMG | NewJeans
# 꽃 | 지수 (JISOO)
# Nostalgia | 우디 (Woody)
# Teddy Bear | STAYC(스테이씨)
# 사건의 지평선 | 윤하 (YOUNHA)
# I Don't Think That I Like Her | Charlie Puth
# CHRISTIAN | Zior Park
# 파이팅 해야지 (Feat. 이영지) | 부석순 (SEVENTEEN)
# 심(心) | DK(디셈버)
# Attention | NewJeans
# After LIKE | IVE (아이브)
# 사랑하기 싫어 | 지아
# ANTIFRAGILE | LE SSERAFIM (르세라핌)
# 밤이 무서워요 (Lonely Night) | 주주 시크릿
# Love Me Like This | NMIXX
# LOVE DIVE | IVE (아이브)
# 사랑인가 봐 | 멜로망스
# 벚꽃 엔딩 | 버스커 버스커
# NIGHT DANCER | imase
# Like Crazy | 지민
# 나비무덤 | 포맨 (4MEN)
# 너를 보는게 지친 하루에 | 송하예
# Dangerously | Charlie Puth
# 봄 사랑 벚꽃 말고 | HIGH4 (하이포)
# 사랑은 늘 도망가 | 임영웅
# 결국엔 너에게 닿아서 | WSG워너비 (가야G)
# Candy | NCT DREAM
# 건물 사이에 피어난 장미 (Rose Blossom) | H1-KEY (하이키)
# VIBE (feat. Jimin of BTS) | 태양
# 너의 모든 순간 | 성시경
# Nxde | (여자)아이들
# Expectations | Anne-Marie
# Say I Love You | 우디 (Woody)
# Monologue | 테이
# That's Hilarious | Charlie Puth
# 새삥 (Prod. ZICO) (Feat. 호미들) | 지코 (ZICO)
# 해요 (2022) | #안녕
# Cookie | NewJeans
# 우연히 봄 | 로꼬
# 취중고백 | 김민석 (멜로망스)
# on the street (with J. Cole) | j-hope
# STAY | The Kid LAROI
# 그라데이션 | 10CM
# Shut Down | BLACKPINK
# 내가 아니라도 | 주호
# TOMBOY | (여자)아이들
# 정이라고 하자 (Feat. 10CM) | BIG Naughty (서동현)

# %%
songs = driver.find_elements(By.CSS_SELECTOR, '#lst100')
songs
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="24bc4a8538758711ca1e5fb15321c864", element="8873525a-98d6-4ce3-a6dd-5352da191707")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="24bc4a8538758711ca1e5fb15321c864", element="44e81b84-9e60-4bb1-a5c9-dfbf1720c815")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="24bc4a8538758711ca1e5fb15321c864", element="24f89a82-dc4b-4bd1-8d6c-397dbe67a11b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="24bc4a8538758711ca1e5fb15321c864", element="c9587fd1-4cd7-42ad-8766-45f7c1ee9e4e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="24bc4a8538758711ca1e5fb15321c864", element="22d1c385-0468-4ea7-857a-54b5247d9667")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="24bc4a8538758711ca1e5fb15321c864", element="f2a119c8-2bda-4482-986c-daa4ec3ca38b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="24bc4a8538758711ca1e5fb15321c864", element="2038f0c6-964f-4fe5-8152-d29f416aaaa8")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="24bc4a8538758711ca1e5fb15321c864", element="56589ed5-f26a-454d-ae03-9c3583580ea9")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="24bc4a8538758711ca1e5fb15321c864", element="342421e2-f868-4cf7-aeb8-19aa03f46933")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="24bc4a8538758711ca1e5fb15321c864", element="44fba504-eb3e-459e-8f88-9d11a2e301e2")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="24bc4a8538758711ca1e5fb15321c864", element="71b887a8-3e72-4a41-9954-c58775322568")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="24bc4a8538758711ca1e5fb15321c864", element="6f9d674d-b06d-4690-b002-78818ab30cce")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="24bc4a8538758711ca1e5fb15321c864", element="3091f722-bed3-40ed-aaed-e7f8ae581b9c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="24bc4a8538758711ca1e5fb15321c864", element="2754a632-c14a-460a-8b13-68c9df14e4eb")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="24bc4a8538758711ca1e5fb15321c864", element="78ccd8fe-4c3d-45cf-9bd5-15fd810ee981")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="24bc4a8538758711ca1e5fb15321c864", element="67a66adf-974b-4ef3-860e-14bb139e35f2")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="24bc4a8538758711ca1e5fb15321c864", element="aa33ef8f-6fb8-4bc2-9325-00cf935efbbc")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="24bc4a8538758711ca1e5fb15321c864", element="f5efb126-44e3-4a36-950d-221eb2ec2108")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="24bc4a8538758711ca1e5fb15321c864", element="ad3bf54f-357f-4de2-9c8d-15c61994eb62")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="24bc4a8538758711ca1e5fb15321c864", element="d7b5705d-f393-4dd7-b472-9404ae830e6f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="24bc4a8538758711ca1e5fb15321c864", element="9d37cd35-874a-4974-abca-b0cc42c26691")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="24bc4a8538758711ca1e5fb15321c864", element="610b2466-3427-4771-9488-f8b5839589eb")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="24bc4a8538758711ca1e5fb15321c864", element="8536886d-281f-4969-bffc-2b8b64ca29fb")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="24bc4a8538758711ca1e5fb15321c864", element="19caeb69-8785-438a-b6ec-6f0afeb6b5a6")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="24bc4a8538758711ca1e5fb15321c864", element="6881eea1-3854-4c30-a0ed-4ebb61fcb40b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="24bc4a8538758711ca1e5fb15321c864", element="6d61325d-444e-4c68-a9d9-e5e5aba2f137")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="24bc4a8538758711ca1e5fb15321c864", element="9259b4ce-147d-4efc-b94e-a937f7bc3124")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="24bc4a8538758711ca1e5fb15321c864", element="95352122-1074-44e2-99ad-ed59e645abcd")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="24bc4a8538758711ca1e5fb15321c864", element="e6fd0340-f763-41c1-aae9-c508cffc42e2")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="24bc4a8538758711ca1e5fb15321c864", element="7362ebc3-5926-4952-94fd-b9d596873626")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="24bc4a8538758711ca1e5fb15321c864", element="b1f8d45e-9f9b-4a1c-b34a-040c33f1b5c3")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="24bc4a8538758711ca1e5fb15321c864", element="141b4e82-29f3-42a9-8ca1-cf3274771273")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="24bc4a8538758711ca1e5fb15321c864", element="d09e6d23-4d61-4c3f-acec-5f95af3c9e2f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="24bc4a8538758711ca1e5fb15321c864", element="80dbae40-e5b2-4b9a-8f71-efbf39dcd7c8")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="24bc4a8538758711ca1e5fb15321c864", element="223a4157-07c5-4ff9-97f5-5027d6232fcf")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="24bc4a8538758711ca1e5fb15321c864", element="1974ac35-7553-4696-a0a7-b916bc849d74")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="24bc4a8538758711ca1e5fb15321c864", element="ed79a900-c501-41e6-9d9b-b2143f23dc8f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="24bc4a8538758711ca1e5fb15321c864", element="c6b228c2-00bb-4a4c-997a-f358d5875455")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="24bc4a8538758711ca1e5fb15321c864", element="987e3376-64c4-4b72-9126-6c7786186a58")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="24bc4a8538758711ca1e5fb15321c864", element="0d146fd4-b2a6-48e1-959e-cc1756310ed7")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="24bc4a8538758711ca1e5fb15321c864", element="696b13a3-ee85-4cb4-9cfe-35f3092ef4d7")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="24bc4a8538758711ca1e5fb15321c864", element="6ea0ac02-e21d-4bee-89e3-d505f0248030")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="24bc4a8538758711ca1e5fb15321c864", element="7279329f-bbfb-49fb-a58f-0e438d868b18")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="24bc4a8538758711ca1e5fb15321c864", element="7dd92302-30b1-4f9b-9efc-bc7f93ba2c4b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="24bc4a8538758711ca1e5fb15321c864", element="322196d8-6845-4b3a-89d8-60c34d955455")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="24bc4a8538758711ca1e5fb15321c864", element="f230c0ca-0de4-4acd-9942-afaf5911e074")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="24bc4a8538758711ca1e5fb15321c864", element="3e49d381-1f0b-47ad-a4f3-5ec8b08f6525")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="24bc4a8538758711ca1e5fb15321c864", element="a884f912-231b-4d44-b89c-85890cd9c08e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="24bc4a8538758711ca1e5fb15321c864", element="cd4ed608-c1f3-4c98-be8e-c49dfd3fbb9c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="24bc4a8538758711ca1e5fb15321c864", element="45e91198-4d96-4907-b351-eb85e583f4f3")>]

# %%
for song in songs:
    title = song.find_elements(By.CSS_SELECTOR,'div.ellipsis.rank01 > span > a')[0].text
    singer = song.find_elements(By.CSS_SELECTOR,'div.ellipsis.rank02 > a')[0].text
    print(title, singer, sep = ' | ')
# Out:
# Young, Dumb, Stupid | NMIXX
# 그때 그 순간 그대로 (그그그) | WSG워너비 (가야G)
# Unholy | Sam Smith
# 다정히 내 이름을 부르면 | 경서예지
# Pink Venom | BLACKPINK
# 봄날 | 방탄소년단
# 되돌리다 | 먼데이 키즈 (Monday Kiz)
# Set Me Free Pt.2 | 지민
# FEARLESS | LE SSERAFIM (르세라핌)
# 우리들의 블루스 | 임영웅
# 오르트구름 | 윤하 (YOUNHA)
# Dynamite | 방탄소년단
# NOT SORRY (Feat. pH-1) (Prod. by Slom) | 이영지
# ELEVEN | IVE (아이브)
# Poppy (Korean Ver.) | STAYC(스테이씨)
# 사랑이라 믿었던 것들은 (Feat. 이수현) | BIG Naughty (서동현)
# 나의 X에게 | 경서
# Rush Hour (Feat. j-hope of BTS) | Crush
# 나만, 봄 | 볼빨간사춘기
# 모든 날, 모든 순간 (Every day, Every Moment) | 폴킴
# 그대를 알고 | 송하예
# 혼자가 아닌 나 | 정효빈
# 딱 10CM만 | 10CM
# 잘가요 | 주호
# 아모르 파티 | 이홍기 (FT아일랜드)
# That That (prod. & feat. SUGA of BTS) | 싸이 (PSY)
# Sugar Rush Ride | 투모로우바이투게더
# Off My Face | Justin Bieber
# 그대라는 사치 | 임창정
# Dreamers [Music from the FIFA World Cup Qatar 2022 Official Soundtrack] (Feat. FIFA Sound) | 정국
# 너와 함께 | 김민석 (멜로망스)
# 다시 만날 수 있을까 | 임영웅
# Butter | 방탄소년단
# 마지막 사랑 | 신예영
# London Boy | 임영웅
# 이제 나만 믿어요 | 임영웅
# 그댄 행복에 살텐데 (2022) | 최유리
# 자격지심 (Feat. ZICO) | BE'O (비오)
# LOVE me | BE'O (비오)
# Polaroid | 임영웅
# 봄이 좋냐?? | 10CM
# 봄여름가을겨울 (Still Life) | BIGBANG (빅뱅)
# 네가 보고 싶은 건 자연스러운 거겠지 | 신예영
# 밤하늘의 별을(2020) | 경서
# All Eyes On Me | 지수 (JISOO)
# Permission to Dance | 방탄소년단
# Love story | 볼빨간사춘기
# 흔들리는 꽃들 속에서 네 샴푸향이 느껴진거야 | 장범준
# 무지개 | 임영웅
# 내 기쁨은 너가 벤틀리를 끄는 거야 | 김승민
