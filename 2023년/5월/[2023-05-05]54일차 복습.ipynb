# %% [markdown]
# ## 주제 선정 생각한 것

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 카드개발 – 소비 패턴 분석
# 저는 저희가 조사한 카테고리 내에서 주제를 선정하는게 시간상으로나 자료 조사면에서 효율적일 것이라 생각되서 평가 했던 표를 보면서 생각해봤는데요. 결국 선정했던 주제 중에서는 다양한 경제지표와 카드매출 등을 메인 주제로 활용하는 방향이 데이터 시각화나 머신러닝을 다양하게 다뤄볼 만하다고 생각되었어요. 주제명은 예를 들면 ‘카드 소비데이터를 사용한 지역별 매출 예측 서비스’와 같이 붙일 수 도 있을 듯 해요. 경제 예측 모델을 제시하고 시간 상 가능하다면 서비스까지 구현하는 것이 낫지 않을까 생각합니다. 물론, 인구이동(생활이동), 서울시민의 업종별 카드소비 패턴 데이터이외에 크롤링을 통한 데이터확보나 기존의 분석 사례들과는 차별점이 있을 만한 인사이트를 찾아내는 것이 필요할 것 같긴 합니다. 서비스 구현에 대해서는 찾아보긴 했는데 구체적인 추천 알고리즘이 어떤방식 인지 감이 안오지만 연령대별또는 지역별, 아니면 특정 세대 등 어떠한 소비 패턴이 유사한 사용자에게 상품을 추천해주는 서비스를 구현할 수 있지 않을까 생각해봤습니다. 만약 챗봇이면 대화를 통해 개인에게 맞는 추천상품을 추천할 수 있는 서비스를 구현할수도 있지 않을까 생각해봤습니다.

# %% [markdown]
# ### chat GPT에 물어본 예상 주제
# 1. **지역별 경제 활성화 정책 분석**<br>
# 경제지표와 카드매출 데이터를 활용하여 지역별로 경제 활성화를 위한 정책을 분석할 수 있습니다. 예를 들어, 지역별로 취업률과 경제성장률이 높은 지역, 소비성향이 변화하는 지역 등을 파악하여 해당 지역의 특성에 맞는 경제 정책을 제시할 수 있습니다.
#
# 2. **소비트렌드 분석**<br>
# 경제지표와 카드매출 데이터를 활용하여 소비 트렌드를 분석할 수 있습니다. 예를 들어, 어떤 카테고리의 제품이 인기 있는지, 어떤 연령층이 어떤 제품을 많이 구매하는지 등을 파악하여, 해당 제품의 마케팅 전략을 구체화할 수 있습니다.
#
# 3. **실업률과 경제성장률 분석**<br>
# 경제지표와 카드매출 데이터를 활용하여 실업률과 경제성장률 간의 관계를 분석할 수 있습니다. 예를 들어, 코로나19 대유행 이후 실업률과 경제성장률의 변화 추세가 어떻게 되는지, 실업률과 소비량 간의 관계는 어떠한지 등을 분석하여, 정책 방향성을 제시할 수 있습니다.
#
# 4. **지역별 매출 예측 서비스**<br>
# 카드매출 데이터와 경제지표 데이터를 활용하여, 지역별 매출을 예측하는 서비스를 개발할 수 있습니다. 예를 들어, 지역별 경제지표와 과거 카드매출 데이터를 기반으로 머신러닝 알고리즘을 적용하여 미래 매출을 예측하는 모델을 학습시키고, 이를 토대로 지역별 매출 예측 결과를 제공하는 서비스를 제공할 수 있습니다.
