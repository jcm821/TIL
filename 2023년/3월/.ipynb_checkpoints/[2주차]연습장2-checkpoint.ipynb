# %%
import pandas as pd
csvFile = 'C:/Users/chunc/Desktop/취업캠프/python/python/pandas/pandas/applyTest.csv'

# %%
df = pd.read_csv(csvFile)
df
# Out:
#    op1  op2  result
# 0    3    5     NaN
# 1    7    6     NaN
# 2    6    7     NaN
# 3    4   98     NaN
# 4    3    8     NaN
# 5    1    6     NaN

# %%
df.drop('result', axis = 1, inplace = True)

# %%
df
# Out:
#    op1  op2
# 0    3    5
# 1    7    6
# 2    6    7
# 3    4   98
# 4    3    8
# 5    1    6

# %%
df['result'] = df.apply(lambda x: x['op1'] * x['op2'], axis = 1)

# %%
df
# Out:
#    op1  op2  result
# 0    3    5      15
# 1    7    6      42
# 2    6    7      42
# 3    4   98     392
# 4    3    8      24
# 5    1    6       6

# %%
my_add = lambda x: x['op1'] + x['op2']
df['result'] = df.apply(my_add, axis = 1)
df
# Out:
#    op1  op2  result
# 0    3    5       8
# 1    7    6      13
# 2    6    7      13
# 3    4   98     102
# 4    3    8      11
# 5    1    6       7

# %%
csvFile1 = 'C:/Users/chunc/Desktop/취업캠프/python/python/pandas/pandas/applyTest2.csv'
df2 = pd.read_csv(csvFile1)
df2
# Out:
#       1    2   3     4
# 0     I  am    a   boy
# 1   You  are  a   girl
# 2  This   is  a    pen

# %%
my_add = lambda x: x[0].strip() + ' ' + x[1].strip() + ' ' + x[2].strip() + ' ' + x[3].strip()
df2['result'] = df2.apply(my_add, axis = 1)
df2
# Out:
#       1    2   3     4          result
# 0     I  am    a   boy      I am a boy
# 1   You  are  a   girl  You are a girl
# 2  This   is  a    pen   This is a pen

# %%
col = ['1', '2']
df2[col].apply(lambda x: print(x), axis = 1)
# Out:
# 1      I
# 2    am
# Name: 0, dtype: object
# 1    You
# 2    are
# Name: 1, dtype: object
# 1    This
# 2      is
# Name: 2, dtype: object
# 0    None
# 1    None
# 2    None
# dtype: object

# %%
# 타이타닉 데이터로 문자열 연습
import pandas as pd
csvFile = 'C:/Users/chunc/Desktop/취업캠프/python/python/train.csv'
df = pd.read_csv(csvFile)
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df['Name'][0].split(',')[1].split('.')[0]
# Out:
# ' Mr'

# %%
# 람다함수로 변환
conv_name = lambda x: x.split(',')[1].split('.')[0]
df['Title'] = df['Name'].map(conv_name)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Title
# 0      0         A/5 21171   7.2500   NaN        S     Mr
# 1      0          PC 17599  71.2833   C85        C    Mrs
# 2      0  STON/O2. 3101282   7.9250   NaN        S   Miss
# 3      0            113803  53.1000  C123        S    Mrs
# ...

# %%
mydf = pd.read_csv('C:/Users/chunc/Desktop/취업캠프/python/python/dataframe_test.csv', encoding = 'euc-kr')
mydf
# Out:
#    이름     그룹
# 0   뷔  방탄소년단
# 1  화사    마마무
# 2  정국  방탄소년단
# 3  민현   뉴이스트
# 4  소연    아이들

# %%
addList = ['남자', '여자', '남자', '남자', '여자']
mydf['성별'] = 0
for i, data in enumerate(addList):
    mydf['성별'][i] = data
# Out:
# C:\Users\chunc\AppData\Local\Temp\ipykernel_39908\2600081389.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mydf['성별'][i] = data

# %%
mydf
# Out:
#    이름     그룹  성별
# 0   뷔  방탄소년단  남자
# 1  화사    마마무  여자
# 2  정국  방탄소년단  남자
# 3  민현   뉴이스트  남자
# 4  소연    아이들  여자

# %%
# pd.Series함수
mydf = pd.read_csv('C:/Users/chunc/Desktop/취업캠프/python/python/dataframe_test.csv', encoding = 'euc-kr')
mydf
# Out:
#    이름     그룹
# 0   뷔  방탄소년단
# 1  화사    마마무
# 2  정국  방탄소년단
# 3  민현   뉴이스트
# 4  소연    아이들

# %%
addList = ['남자', '여자', '남자', '남자', '여자']
mydf['성별'] = pd.Series(addList)
mydf
# Out:
#    이름     그룹  성별
# 0   뷔  방탄소년단  남자
# 1  화사    마마무  여자
# 2  정국  방탄소년단  남자
# 3  민현   뉴이스트  남자
# 4  소연    아이들  여자

# %%
mydf = pd.read_csv('C:/Users/chunc/Desktop/취업캠프/python/python/dataframe_test.csv', encoding = 'euc-kr')
mydf
addList = ['남자', '여자', '남자', '남자']
mydf['성별'] = pd.Series(addList)

# %%
mydf
# Out:
#    이름     그룹   성별
# 0   뷔  방탄소년단   남자
# 1  화사    마마무   여자
# 2  정국  방탄소년단   남자
# 3  민현   뉴이스트   남자
# 4  소연    아이들  NaN

# %%
mydf['성별'][4] = '여자'

# %%
mydf
# Out:
#    이름     그룹  성별
# 0   뷔  방탄소년단  남자
# 1  화사    마마무  여자
# 2  정국  방탄소년단  남자
# 3  민현   뉴이스트  남자
# 4  소연    아이들  여자

# %%
df = pd.read_csv('C:/Users/chunc/Desktop/취업캠프/python/python/korean-idol.csv')
df.head()
df2 = df.copy()
df2
# Out:
#       이름     그룹      소속사  성별        생년월일      키 혈액형   브랜드평판지수
# 0     지민  방탄소년단      빅히트  남자  1995-10-13  173.6   A  10523260
# 1   지드래곤     빅뱅       YG  남자  1988-08-18  177.0   A   9916947
# 2   강다니엘    NaN      커넥트  남자  1996-12-10  180.0   A   8273745
# 3      뷔  방탄소년단      빅히트  남자  1995-12-30  178.0  AB   8073501
# 4     화사    마마무      RBW  여자  1995-07-23  162.1   A   7650928
# 5     정국  방탄소년단      빅히트  남자  1997-09-01  178.0   A   5208335
# 6     민현   뉴이스트     플레디스  남자  1995-08-09  182.3   O   4989792
# 7     소연    아이들       큐브  여자  1998-08-26    NaN   B   4668615
# 8      진  방탄소년단      빅히트  남자  1992-12-04  179.2   O   4570308
# 9    하성운     핫샷  스타크루이엔티  남자  1994-03-22  167.1   A   4036489
# 10    태연   소녀시대       SM  여자  1989-03-09    NaN   A   3918661
# 11   차은우   아스트로     판타지오  남자  1997-03-30  183.0   B   3506027
# 12    백호   뉴이스트     플레디스  남자  1995-07-21  175.0  AB   3301654
# 13    JR   뉴이스트     플레디스  남자  1995-06-08  176.0   O   3274137
# ...

# %%
height = df2['키'].mode()

# %%
type(height)
# Out:
# pandas.core.series.Series

# %%
df2['키'].fillna(height[0], inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   이름       15 non-null     object
#  1   그룹       14 non-null     object
#  2   소속사      15 non-null     object
#  3   성별       15 non-null     object
#  4   생년월일     15 non-null     object
#  5   키        13 non-null     float64
#  6   혈액형      15 non-null     object
#  7   브랜드평판지수  15 non-null     int64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 1.1+ KB

# %%
df['생년월일'] = pd.to_datetime(df['생년월일'])
df['생년월일']
# Out:
# 0    1995-10-13
# 1    1988-08-18
# 2    1996-12-10
# 3    1995-12-30
# 4    1995-07-23
# 5    1997-09-01
# 6    1995-08-09
# 7    1998-08-26
# 8    1992-12-04
# 9    1994-03-22
# 10   1989-03-09
# 11   1997-03-30
# 12   1995-07-21
# 13   1995-06-08
# 14   1993-03-09
# Name: 생년월일, dtype: datetime64[ns]

# %%
df['생년월일'].dt.dayofweek
# Out:
# 0     4
# 1     3
# 2     1
# 3     5
# 4     6
# 5     0
# 6     2
# 7     2
# 8     4
# 9     1
# 10    3
# 11    6
# 12    4
# 13    3
# 14    1
# Name: 생년월일, dtype: int64

# %%
df['생년월일'].dt.year
# Out:
# 0     1995
# 1     1988
# 2     1996
# 3     1995
# 4     1995
# 5     1997
# 6     1995
# 7     1998
# 8     1992
# 9     1994
# 10    1989
# 11    1997
# 12    1995
# 13    1995
# 14    1993
# Name: 생년월일, dtype: int64

# %%
df['생년월일'].dt.month
# Out:
# 0     10
# 1      8
# 2     12
# 3     12
# 4      7
# 5      9
# 6      8
# 7      8
# 8     12
# 9      3
# 10     3
# 11     3
# 12     7
# 13     6
# 14     3
# Name: 생년월일, dtype: int64

# %%
df['생일_년'] = df['생년월일'].dt.year
df['생일_월'] = df['생년월일'].dt.month
df['생일_일'] = df['생년월일'].dt.day
df.head()
# Out:
#      이름     그룹  소속사  성별       생년월일      키 혈액형   브랜드평판지수  생일_년  생일_월  생일_일
# 0    지민  방탄소년단  빅히트  남자 1995-10-13  173.6   A  10523260  1995    10    13
# 1  지드래곤     빅뱅   YG  남자 1988-08-18  177.0   A   9916947  1988     8    18
# 2  강다니엘    NaN  커넥트  남자 1996-12-10  180.0   A   8273745  1996    12    10
# 3     뷔  방탄소년단  빅히트  남자 1995-12-30  178.0  AB   8073501  1995    12    30
# 4    화사    마마무  RBW  여자 1995-07-23  162.1   A   7650928  1995     7    23

# %%
# apply
import pandas as pd
df = pd.read_csv('C:/Users/chunc/Desktop/취업캠프/python/python/korean-idol.csv')
df.head()
# Out:
#      이름     그룹  소속사  성별        생년월일      키 혈액형   브랜드평판지수
# 0    지민  방탄소년단  빅히트  남자  1995-10-13  173.6   A  10523260
# 1  지드래곤     빅뱅   YG  남자  1988-08-18  177.0   A   9916947
# 2  강다니엘    NaN  커넥트  남자  1996-12-10  180.0   A   8273745
# 3     뷔  방탄소년단  빅히트  남자  1995-12-30  178.0  AB   8073501
# 4    화사    마마무  RBW  여자  1995-07-23  162.1   A   7650928

# %%
df.loc[df['성별'] == '남자', '성별'] = 1
df.loc[df['성별'] == '여자', '성별'] = 0

# %%
df
# Out:
#       이름     그룹      소속사 성별        생년월일      키 혈액형   브랜드평판지수
# 0     지민  방탄소년단      빅히트  1  1995-10-13  173.6   A  10523260
# 1   지드래곤     빅뱅       YG  1  1988-08-18  177.0   A   9916947
# 2   강다니엘    NaN      커넥트  1  1996-12-10  180.0   A   8273745
# 3      뷔  방탄소년단      빅히트  1  1995-12-30  178.0  AB   8073501
# 4     화사    마마무      RBW  0  1995-07-23  162.1   A   7650928
# 5     정국  방탄소년단      빅히트  1  1997-09-01  178.0   A   5208335
# 6     민현   뉴이스트     플레디스  1  1995-08-09  182.3   O   4989792
# 7     소연    아이들       큐브  0  1998-08-26    NaN   B   4668615
# 8      진  방탄소년단      빅히트  1  1992-12-04  179.2   O   4570308
# 9    하성운     핫샷  스타크루이엔티  1  1994-03-22  167.1   A   4036489
# 10    태연   소녀시대       SM  0  1989-03-09    NaN   A   3918661
# 11   차은우   아스트로     판타지오  1  1997-03-30  183.0   B   3506027
# 12    백호   뉴이스트     플레디스  1  1995-07-21  175.0  AB   3301654
# 13    JR   뉴이스트     플레디스  1  1995-06-08  176.0   O   3274137
# ...

# %%
# 람다함수
f = lambda x: 1 if x == '남자' else 0

# %%
df['성별'].apply(f)
# Out:
# 0     1
# 1     1
# 2     1
# 3     1
# 4     0
# 5     1
# 6     1
# 7     0
# 8     1
# 9     1
# 10    0
# 11    1
# 12    1
# 13    1
# 14    1
# Name: 성별, dtype: int64

# %%
# 람다함수 예
score = lambda x:'A등급' if x >= 80 else 'B등급'

# %%
# 람다함수 사용한 경우
male_or_female = lambda x:1 if x == '남자' else 0
df['성별_NEW'] = df['성별'].apply(male_or_female)

# %%
df
# Out:
#       이름     그룹      소속사  성별        생년월일      키 혈액형   브랜드평판지수  성별_NEW
# 0     지민  방탄소년단      빅히트  남자  1995-10-13  173.6   A  10523260       1
# 1   지드래곤     빅뱅       YG  남자  1988-08-18  177.0   A   9916947       1
# 2   강다니엘    NaN      커넥트  남자  1996-12-10  180.0   A   8273745       1
# 3      뷔  방탄소년단      빅히트  남자  1995-12-30  178.0  AB   8073501       1
# 4     화사    마마무      RBW  여자  1995-07-23  162.1   A   7650928       0
# 5     정국  방탄소년단      빅히트  남자  1997-09-01  178.0   A   5208335       1
# 6     민현   뉴이스트     플레디스  남자  1995-08-09  182.3   O   4989792       1
# 7     소연    아이들       큐브  여자  1998-08-26    NaN   B   4668615       0
# 8      진  방탄소년단      빅히트  남자  1992-12-04  179.2   O   4570308       1
# 9    하성운     핫샷  스타크루이엔티  남자  1994-03-22  167.1   A   4036489       1
# 10    태연   소녀시대       SM  여자  1989-03-09    NaN   A   3918661       0
# 11   차은우   아스트로     판타지오  남자  1997-03-30  183.0   B   3506027       1
# ...

# %%
df['키/2'] = df['키'].apply(lambda x: x/2)

# %%
df.head()
# Out:
#      이름     그룹  소속사  성별        생년월일      키 혈액형   브랜드평판지수  성별_NEW    키/2
# 0    지민  방탄소년단  빅히트  남자  1995-10-13  173.6   A  10523260       1  86.80
# 1  지드래곤     빅뱅   YG  남자  1988-08-18  177.0   A   9916947       1  88.50
# 2  강다니엘    NaN  커넥트  남자  1996-12-10  180.0   A   8273745       1  90.00
# 3     뷔  방탄소년단  빅히트  남자  1995-12-30  178.0  AB   8073501       1  89.00
# 4    화사    마마무  RBW  여자  1995-07-23  162.1   A   7650928       0  81.05

# %%
df['키'].apply(lambda x: x**2)
# Out:
# 0     30136.96
# 1     31329.00
# 2     32400.00
# 3     31684.00
# 4     26276.41
# 5     31684.00
# 6     33233.29
# 7          NaN
# 8     32112.64
# 9     27922.41
# 10         NaN
# 11    33489.00
# 12    30625.00
# 13    30976.00
# 14    30276.00
# Name: 키, dtype: float64

# %%
# map함수
my_map = {
    '남자': 1,
    '여자': 0
}

# %%
df['성별'].map(my_map)
# Out:
# 0     1
# 1     1
# 2     1
# 3     1
# 4     0
# 5     1
# 6     1
# 7     0
# 8     1
# 9     1
# 10    0
# 11    1
# 12    1
# 13    1
# 14    1
# Name: 성별, dtype: int64

# %%
import pandas as pd
csvFile = 'C:/Users/chunc/Desktop/취업캠프/python/python/pandas/pandas/applyTest.csv'

# %%
df = pd.read_csv(csvFile)
df
# Out:
#    op1  op2  result
# 0    3    5     NaN
# 1    7    6     NaN
# 2    6    7     NaN
# 3    4   98     NaN
# 4    3    8     NaN
# 5    1    6     NaN

# %%
df.drop('result', axis = 1, inplace = True)

# %%
df
# Out:
#    op1  op2
# 0    3    5
# 1    7    6
# 2    6    7
# 3    4   98
# 4    3    8
# 5    1    6

# %%
# op1 * op2 = result계산하는 람다함수 생성, apply와 map함수 사용해서 'result'컬럼에 저장하기
# 방법1
my_add = lambda x: x['op1'] + x['op2']
df['result'] = df.apply(my_add, axis = 1)

# %%
df
# Out:
#    op1  op2  result
# 0    3    5       8
# 1    7    6      13
# 2    6    7      13
# 3    4   98     102
# 4    3    8      11
# 5    1    6       7

# %%
# 방법2
df['result'] = df.apply(lambda x: x['op1'] + x['op2'], axis = 1)

# %%
df
# Out:
#    op1  op2  result
# 0    3    5       8
# 1    7    6      13
# 2    6    7      13
# 3    4   98     102
# 4    3    8      11
# 5    1    6       7

# %%
csvFile1 = 'C:/Users/chunc/Desktop/취업캠프/python/python/pandas/pandas/applyTest2.csv'
df2 = pd.read_csv(csvFile1)
df2
# Out:
#       1    2   3     4
# 0     I  am    a   boy
# 1   You  are  a   girl
# 2  This   is  a    pen

# %%
my_add = lambda x: x[0].strip() + ' ' + x[1].strip() + ' ' + x[2].strip() + ' ' + x[3].strip()
df2['result'] = df2.apply(my_add, axis = 1)
df2
# Out:
#       1    2   3     4          result
# 0     I  am    a   boy      I am a boy
# 1   You  are  a   girl  You are a girl
# 2  This   is  a    pen   This is a pen

# %%
#  참조하고 싶은 칼럼만 추출하고 싶을때
col = ['1', '2']
df2[col].apply(lambda x: print(x), axis = 1)
# Out:
# 1      I
# 2    am
# Name: 0, dtype: object
# 1    You
# 2    are
# Name: 1, dtype: object
# 1    This
# 2      is
# Name: 2, dtype: object
# 0    None
# 1    None
# 2    None
# dtype: object

# %%
# for문 예제
names = ['James', 'Robert', 'Lisa', 'Mary']
scores = [95, 96, 97, 94]
for k in range(len(names)):
    print(names[k], scores[k])
# Out:
# James 95
# Robert 96
# Lisa 97
# Mary 94

# %%
# zip함수를 사용한 for문
# 길이가 같은 여러개의 리스트를 처리해야 할경우 zip()함수를 이용한다
for name, score in zip(names, scores):
    print(name, score)
# Out:
# James 95
# Robert 96
# Lisa 97
# Mary 94

# %%
# while문 연습
i = 0
sum = 0
while (sum < 20):
    i += 1
    sum += i
    print(i, sum)
# Out:
# 1 1
# 2 3
# 3 6
# 4 10
# 5 15
# 6 21

# %%
# 데이터 불러오기
import pandas as pd
csvFile = 'C:/Users/chunc/Desktop/취업캠프/python/python/01. CCTV_in_Seoul.csv'
xlsFile = 'C:/Users/chunc/Desktop/취업캠프/python/python/01. population_in_Seoul.xls'

# %%
# CCTV데이터 읽어오기
CCTV_df = pd.read_csv(csvFile)
CCTV_df.head()
# Out:
#    기관명    소계  2013년도 이전  2014년  2015년  2016년
# 0  강남구  2780       1292    430    584    932
# 1  강동구   773        379     99    155    377
# 2  강북구   748        369    120    138    204
# 3  강서구   884        388    258    184     81
# 4  관악구  1496        846    260    390    613

# %%
CCTV_df.columns
# Out:
# Index(['기관명', '소계', '2013년도 이전', '2014년', '2015년', '2016년'], dtype='object')

# %%
CCTV_df.columns = ['구별', '소계', '2013년도 이전', '2014년', '2015년', '2016년']
CCTV_df.columns
# Out:
# Index(['구별', '소계', '2013년도 이전', '2014년', '2015년', '2016년'], dtype='object')

# %%
# rename 함수
CCTV_df.rename(columns = {CCTV_df.columns[0]: '구별'}, inplace = True)

# %%
CCTV_df.head()
# Out:
#     구별    소계  2013년도 이전  2014년  2015년  2016년
# 0  강남구  2780       1292    430    584    932
# 1  강동구   773        379     99    155    377
# 2  강북구   748        369    120    138    204
# 3  강서구   884        388    258    184     81
# 4  관악구  1496        846    260    390    613

# %%
# pop데이터 불러오기
pop_df = pd.read_excel(xlsFile, header = 2, usecols = 'B, D, G, J, N')
pop_df.head()
# Out:
#    자치구           계        계.1       계.2   65세이상고령자
# 0   합계  10197604.0  9926968.0  270636.0  1321458.0
# 1  종로구    162820.0   153589.0    9231.0    25425.0
# 2   중구    133240.0   124312.0    8928.0    20764.0
# 3  용산구    244203.0   229456.0   14747.0    36231.0
# 4  성동구    311244.0   303380.0    7864.0    39997.0

# %%
pop_df.rename(columns = {'자치구':'구별', '계':'인구수', '계.1':'한국인', '계.2':'외국인', '65세이상고령자':'고령자'},inplace = True)

# %%
pop_df.head()
# Out:
#     구별         인구수        한국인       외국인        고령자
# 0   합계  10197604.0  9926968.0  270636.0  1321458.0
# 1  종로구    162820.0   153589.0    9231.0    25425.0
# 2   중구    133240.0   124312.0    8928.0    20764.0
# 3  용산구    244203.0   229456.0   14747.0    36231.0
# 4  성동구    311244.0   303380.0    7864.0    39997.0

# %%
pop_df.tail()
# Out:
#      구별       인구수       한국인     외국인      고령자
# 22  서초구  450310.0  445994.0  4316.0  51733.0
# 23  강남구  570500.0  565550.0  4950.0  63167.0
# 24  송파구  667483.0  660584.0  6899.0  72506.0
# 25  강동구  453233.0  449019.0  4214.0  54622.0
# 26  NaN       NaN       NaN     NaN      NaN

# %%
pop_df.drop([0,26], inplace = True)

# %%
pop_df
# Out:
#       구별       인구수       한국인      외국인      고령자
# 1    종로구  162820.0  153589.0   9231.0  25425.0
# 2     중구  133240.0  124312.0   8928.0  20764.0
# 3    용산구  244203.0  229456.0  14747.0  36231.0
# 4    성동구  311244.0  303380.0   7864.0  39997.0
# 5    광진구  372164.0  357211.0  14953.0  42214.0
# 6   동대문구  369496.0  354079.0  15417.0  54173.0
# 7    중랑구  414503.0  409882.0   4621.0  56774.0
# 8    성북구  461260.0  449773.0  11487.0  64692.0
# 9    강북구  330192.0  326686.0   3506.0  54813.0
# 10   도봉구  348646.0  346629.0   2017.0  51312.0
# 11   노원구  569384.0  565565.0   3819.0  71941.0
# 12   은평구  494388.0  489943.0   4445.0  72334.0
# 13  서대문구  327163.0  314982.0  12181.0  48161.0
# 14   마포구  389649.0  378566.0  11083.0  48765.0
# 15   양천구  479978.0  475949.0   4029.0  52975.0
# 16   강서구  603772.0  597248.0   6524.0  72548.0
# 17   구로구  447874.0  416487.0  31387.0  56833.0
# 18   금천구  255082.0  236353.0  18729.0  32970.0
# 19  영등포구  402985.0  368072.0  34913.0  52413.0
# ...

# %%
all_df = pd.merge(CCTV_df, pop_df, on = '구별')
all_df.head()
# Out:
#     구별    소계  2013년도 이전  2014년  2015년  2016년       인구수       한국인      외국인  \
# 0  강남구  2780       1292    430    584    932  570500.0  565550.0   4950.0
# 1  강동구   773        379     99    155    377  453233.0  449019.0   4214.0
# 2  강북구   748        369    120    138    204  330192.0  326686.0   3506.0
# 3  강서구   884        388    258    184     81  603772.0  597248.0   6524.0
# 4  관악구  1496        846    260    390    613  525515.0  507203.0  18312.0
#
#        고령자
# 0  63167.0
# 1  54622.0
# 2  54813.0
# 3  72548.0
# 4  68082.0

# %%
all_df.drop(['2013년도 이전', '2014년', '2015년', '2016년'], axis = 1, inplace = True)
all_df.head()
# Out:
#     구별    소계       인구수       한국인      외국인      고령자
# 0  강남구  2780  570500.0  565550.0   4950.0  63167.0
# 1  강동구   773  453233.0  449019.0   4214.0  54622.0
# 2  강북구   748  330192.0  326686.0   3506.0  54813.0
# 3  강서구   884  603772.0  597248.0   6524.0  72548.0
# 4  관악구  1496  525515.0  507203.0  18312.0  68082.0

# %%
import matplotlib.pyplot as plt
plt.figure()
all_df['소계'].plot(kind = 'barh', grid = True, figsize = (10, 10))
plt.show()

# %%
# 인덱스를 구별로 세팅
# set_index()
# 실행 후 위의 그래프 재출력
all_df.set_index('구별', inplace = True)

# %%
plt.figure()
all_df['소계'].sort_values().plot(kind = 'barh', grid = True, figsize = (10, 10))
plt.show()

# %%
all_df['CCTV비율'] = (all_df['소계'] / all_df['인구수']) * 100
plt.figure()
all_df['CCTV비율'].sort_values().plot(kind = 'barh', grid = True, figsize = (10, 10))
plt.show()

# %%
plt.figure(figsize = (10, 8))
plt.scatter(all_df['인구수'], all_df['소계'], s = 50, c= all_df['소계'])
plt.xlabel('인구수')
plt.ylabel('CCTV(소계)')
plt.grid()
plt.colorbar()
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
csvFile = 'C:/Users/chunc/Desktop/취업캠프/python/python/01. CCTV_in_Seoul.csv'
xlsFile = 'C:/Users/chunc/Desktop/취업캠프/python/python/01. population_in_Seoul.xls'

# %%
CCTV_df = pd.read_csv(csvFile)
CCTV_df.head()
# Out:
#    기관명    소계  2013년도 이전  2014년  2015년  2016년
# 0  강남구  2780       1292    430    584    932
# 1  강동구   773        379     99    155    377
# 2  강북구   748        369    120    138    204
# 3  강서구   884        388    258    184     81
# 4  관악구  1496        846    260    390    613

# %%
CCTV_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   기관명        25 non-null     object
#  1   소계         25 non-null     int64
#  2   2013년도 이전  25 non-null     int64
#  3   2014년      25 non-null     int64
#  4   2015년      25 non-null     int64
#  5   2016년      25 non-null     int64
# dtypes: int64(5), object(1)
# memory usage: 1.3+ KB

# %%
CCTV_df.describe()
# Out:
#                 소계    2013년도 이전       2014년       2015년       2016년
# count    25.000000    25.000000   25.000000   25.000000   25.000000
# mean   1179.080000   764.760000  159.480000  205.200000  385.880000
# std     556.728983   415.510257  104.132976  137.877059  182.479981
# min     485.000000   238.000000   21.000000   30.000000   81.000000
# 25%     748.000000   464.000000   78.000000  103.000000  292.000000
# 50%    1015.000000   573.000000  142.000000  184.000000  377.000000
# 75%    1496.000000  1070.000000  218.000000  269.000000  467.000000
# max    2780.000000  1843.000000  430.000000  584.000000  932.000000

# %%
pop_df = pd.read_excel(xlsFile, header = 2, usecols = 'B, D, G, J, N')
pop_df.head()
# Out:
#    자치구           계        계.1       계.2   65세이상고령자
# 0   합계  10197604.0  9926968.0  270636.0  1321458.0
# 1  종로구    162820.0   153589.0    9231.0    25425.0
# 2   중구    133240.0   124312.0    8928.0    20764.0
# 3  용산구    244203.0   229456.0   14747.0    36231.0
# 4  성동구    311244.0   303380.0    7864.0    39997.0

# %%
pop_df.columns = ['구별', '인구수', '한국인', '외국인', '고령자']

# %%
CCTV_df.columns = ['구별', '소계', '2013년도 이전', '2014년', '2015년', '2016년']

# %%
CCTV_df.sort_values(by = '소계', ascending = False).head()[['구별', '소계']]
# Out:
#      구별    소계
# 0   강남구  2780
# 18  양천구  2034
# 14  서초구  1930
# 21  은평구  1873
# 20  용산구  1624

# %%
pop_df
# Out:
#       구별         인구수        한국인       외국인        고령자
# 0     합계  10197604.0  9926968.0  270636.0  1321458.0
# 1    종로구    162820.0   153589.0    9231.0    25425.0
# 2     중구    133240.0   124312.0    8928.0    20764.0
# 3    용산구    244203.0   229456.0   14747.0    36231.0
# 4    성동구    311244.0   303380.0    7864.0    39997.0
# 5    광진구    372164.0   357211.0   14953.0    42214.0
# 6   동대문구    369496.0   354079.0   15417.0    54173.0
# 7    중랑구    414503.0   409882.0    4621.0    56774.0
# 8    성북구    461260.0   449773.0   11487.0    64692.0
# 9    강북구    330192.0   326686.0    3506.0    54813.0
# 10   도봉구    348646.0   346629.0    2017.0    51312.0
# 11   노원구    569384.0   565565.0    3819.0    71941.0
# 12   은평구    494388.0   489943.0    4445.0    72334.0
# 13  서대문구    327163.0   314982.0   12181.0    48161.0
# 14   마포구    389649.0   378566.0   11083.0    48765.0
# 15   양천구    479978.0   475949.0    4029.0    52975.0
# 16   강서구    603772.0   597248.0    6524.0    72548.0
# ...

# %%
pop_df.drop([0, 26], inplace = True)

# %%
pop_df.sort_values(by = '인구수', ascending = False).head()[['구별', '인구수']]
# Out:
#      구별       인구수
# 24  송파구  667483.0
# 16  강서구  603772.0
# 23  강남구  570500.0
# 11  노원구  569384.0
# 21  관악구  525515.0

# %%
pop_df['구별'].isnull()
# Out:
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# Name: 구별, dtype: bool

# %%
pop_df[['구별', '인구수']].isnull()
# Out:
#        구별    인구수
# 1   False  False
# 2   False  False
# 3   False  False
# 4   False  False
# 5   False  False
# 6   False  False
# 7   False  False
# 8   False  False
# 9   False  False
# 10  False  False
# 11  False  False
# 12  False  False
# 13  False  False
# 14  False  False
# 15  False  False
# 16  False  False
# 17  False  False
# 18  False  False
# 19  False  False
# 20  False  False
# 21  False  False
# 22  False  False
# 23  False  False
# 24  False  False
# 25  False  False

# %%
all_df = pd.merge(CCTV_df, pop_df, on = '구별')
all_df
# Out:
#       구별    소계  2013년도 이전  2014년  2015년  2016년       인구수       한국인      외국인  \
# 0    강남구  2780       1292    430    584    932  570500.0  565550.0   4950.0
# 1    강동구   773        379     99    155    377  453233.0  449019.0   4214.0
# 2    강북구   748        369    120    138    204  330192.0  326686.0   3506.0
# 3    강서구   884        388    258    184     81  603772.0  597248.0   6524.0
# 4    관악구  1496        846    260    390    613  525515.0  507203.0  18312.0
# 5    광진구   707        573     78     53    174  372164.0  357211.0  14953.0
# 6    구로구  1561       1142    173    246    323  447874.0  416487.0  31387.0
# 7    금천구  1015        674     51    269    354  255082.0  236353.0  18729.0
# 8    노원구  1265        542     57    451    516  569384.0  565565.0   3819.0
# 9    도봉구   485        238    159     42    386  348646.0  346629.0   2017.0
# 10  동대문구  1294       1070     23    198    579  369496.0  354079.0  15417.0
# ...

# %%
all_df['소계'].plot(kind = 'barh', grid = True, figsize = (8, 8))
# Out:
# <AxesSubplot:>

# %%
all_df.set_index('구별', inplace = True)

# %%
all_df['소계'].plot(kind = 'barh', grid = True, figsize = (8, 8))
# Out:
# <AxesSubplot:ylabel='구별'>

# %%
all_df['소계'].sort_values().plot(kind = 'barh', grid = True, figsize = (8, 8))
# Out:
# <AxesSubplot:ylabel='구별'>

# %%
plt.figure(figsize = (10, 10))

# 2. 산점도로 점을 찍는다
plt.scatter(all_df['인구수'], all_df['소계'], s = 50, c = all_df['소계'])
plt.xlabel('인구수')
plt.ylabel('CCTV(소계)')
plt.grid()

plt.colorbar()

# %%
csvFile = 'C:/Users/chunc/Desktop/취업캠프/python/python/제주특별자치도_태양광발전소현황_20220630.csv'

# %%
solar_df = pd.read_csv(csvFile, encoding = 'euc-kr')
solar_df.head()
# Out:
#    행정시  읍면동        허가일자            상호  설비용량(KW)    상태       사업개시일     데이터기준일자
# 0  제주시  구좌읍  1998-06-10  행원풍력발전단지(1차)    3480.0  사업개시  2000-04-05  2022-06-30
# 1  제주시  회천동  2002-12-09     파낙스에너지(주)    1000.0  사업개시  2002-12-18  2022-06-30
# 2  제주시  한경면  2003-04-14      한경풍력 1단계    6000.0  사업개시  2004-02-28  2022-06-30
# 3  제주시  한경면  2005-04-04      신창풍력발전단지    1700.0  사업개시  2006-03-03  2022-06-30
# 4  제주시  구좌읍  2005-08-30     제주월정풍력발전소    1500.0  사업개시  2006-07-20  2022-06-30

# %%
solar_df['상태'].unique()
# Out:
# array(['사업개시', '공사진행', '인허가'], dtype=object)

# %%
solar_df['상태'] == '사업개시'
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 2143    False
# 2144    False
# 2145    False
# 2146    False
# 2147    False
# Name: 상태, Length: 2148, dtype: bool

# %%
solar_df[solar_df['상태'] == '사업개시']
# Out:
#        행정시  읍면동        허가일자            상호  설비용량(KW)    상태       사업개시일  \
# 0      제주시  구좌읍  1998-06-10  행원풍력발전단지(1차)   3480.00  사업개시  2000-04-05
# 1      제주시  회천동  2002-12-09     파낙스에너지(주)   1000.00  사업개시  2002-12-18
# 2      제주시  한경면  2003-04-14      한경풍력 1단계   6000.00  사업개시  2004-02-28
# 3      제주시  한경면  2005-04-04      신창풍력발전단지   1700.00  사업개시  2006-03-03
# 4      제주시  구좌읍  2005-08-30     제주월정풍력발전소   1500.00  사업개시  2006-07-20
# ...    ...  ...         ...           ...       ...   ...         ...
# 2050  서귀포시  안덕면  2021-04-19      썬 태양광발전소    182.00  사업개시  2022-01-03
# 2051  서귀포시  안덕면  2021-04-19     청춘 태양광발전소    662.48  사업개시  2022-01-03
# 2055  서귀포시  표선면  2021-04-21   제주덕암 태양광발전소     99.18  사업개시  2022-01-03
# 2083  서귀포시  안덕면  2021-08-03    태양7호태양광발전소    198.88  사업개시  2021-12-10
# 2091   제주시  구좌읍  2021-09-15      흥산태양광발전소    999.63  사업개시  2022-04-25
#
#          데이터기준일자
# 0     2022-06-30
# 1     2022-06-30
# 2     2022-06-30
# 3     2022-06-30
# 4     2022-06-30
# ...

# %%
solar_df2 = solar_df[solar_df['상태'] == '사업개시']

# %%
df1 = solar_df2[solar_df2['상호'].str.contains('태양')]
df2 = solar_df2[solar_df2['상호'].str.contains('솔라')]
df3 = solar_df2[solar_df2['상호'].str.contains('쏠라')]
df4 = solar_df2[solar_df2['상호'].str.contains('햇빛')]
df5 = solar_df2[solar_df2['상호'].str.contains('썬')]

# %%
# 함수예제
s1 = pd.Series(['Mouse', 'dog', 'house and parrot', '23', np.NaN])
s1.str.contains('og', regex = False)
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# 4      NaN
# dtype: object

# %%
myStr = pd.Series(['Dog', 'dog', 'DOG', 'cat'])
myStr.str.contains('og')
# Out:
# 0     True
# 1     True
# 2    False
# 3    False
# dtype: bool

# %%
pd.concat([df1, df2, df3, df4, df5])
# Out:
#        행정시  읍면동        허가일자             상호  설비용량(KW)    상태       사업개시일  \
# 18    서귀포시  안덕면  2007-12-14    번내태양광발전주식회사     90.72  사업개시  2008-05-13
# 19    서귀포시  안덕면  2007-12-14    번내태양광발전주식회사     90.72  사업개시  2008-05-13
# 20    서귀포시  성산읍  2007-12-26  제주태양에너지발전주식회사   1000.00  사업개시  2009-02-26
# 22     제주시  한경면  2007-12-28  (유)케이엔디태양광발전소     80.00  사업개시  2008-04-21
# 24    서귀포시  남원읍  2008-01-10    복미태양광발전주식회사     99.90  사업개시  2009-09-21
# ...    ...  ...         ...            ...       ...   ...         ...
# 1324   제주시  한경면  2018-09-20     썬파워 태양광발전소     98.82  사업개시  2022-01-26
# 1501  서귀포시  남원읍  2019-02-11        신생썬 에너지    296.40  사업개시  2020-10-20
# 1805   제주시  한경면  2020-04-14          더썬에너지     99.60  사업개시  2022-06-02
# 1844  서귀포시  안덕면  2020-06-03      썬파워태양광발전소    302.40  사업개시  2021-08-31
# 2050  서귀포시  안덕면  2021-04-19       썬 태양광발전소    182.00  사업개시  2022-01-03
#
#          데이터기준일자
# 18    2022-06-30
# 19    2022-06-30
# 20    2022-06-30
# 22    2022-06-30
# 24    2022-06-30
# ...

# %%
csvFile = 'C:/Users/chunc/Desktop/취업캠프/python/python/제주특별자치도_신재생에너지발전시설현황_20200120.csv'

# %%
energy_df = pd.read_csv(csvFile, encoding = 'euc-kr')
energy_df
# Out:
#            허가일자                        상호  설비용량(KW) 설치행정시 설치지역 원동력종류  \
# 0      2018.4.4           (유)나월(나월태양광발전소)    496.80   제주시  애월읍   태양광
# 1     2014.10.7            (유)메가솔라 태양광발전소   1800.00   제주시  구좌읍   태양광
# 2     2014.5.15  (유)무한에코에너지(서민행복8호태양광발전소)    516.00  서귀포시  남원읍   태양광
# 3     2014.12.9             (유)용흥마을태양광발전소     99.00  서귀포시  강정동   태양광
# 4    2014.10.14                 (유)제주 늘해랑   2198.00  서귀포시  성산읍   태양광
# ..          ...                       ...       ...   ...  ...   ...
# 836   2018.9.19                후니3 태양광발전소     93.15  서귀포시  표선면   태양광
# 837  2014.10.28                희윤2 태양광발전소     99.00  서귀포시  성산읍   태양광
# 838  2014.10.29                희윤4 태양광발전소     99.28  서귀포시  성산읍   태양광
# 839  2014.10.29                희윤5 태양광발전소     99.28  서귀포시  성산읍   태양광
# 840  2014.10.29                  희윤태양광발전소     99.28  서귀포시  성산읍   태양광
#
#           사업개시일  구분    데이터기준일자
# 0     2019.4.26  육상  2020.1.20
# 1      2015.7.1  없음  2020.1.20
# 2    2014.10.16  없음  2020.1.20
# ...

# %%
energy_df['원동력종류'].unique()
# Out:
# array(['태양광', '바이오가스', '수력', '풍력'], dtype=object)

# %%
solar_df = energy_df[energy_df['원동력종류'] == '태양광']
solar_df
# Out:
#            허가일자                        상호  설비용량(KW) 설치행정시 설치지역 원동력종류  \
# 0      2018.4.4           (유)나월(나월태양광발전소)    496.80   제주시  애월읍   태양광
# 1     2014.10.7            (유)메가솔라 태양광발전소   1800.00   제주시  구좌읍   태양광
# 2     2014.5.15  (유)무한에코에너지(서민행복8호태양광발전소)    516.00  서귀포시  남원읍   태양광
# 3     2014.12.9             (유)용흥마을태양광발전소     99.00  서귀포시  강정동   태양광
# 4    2014.10.14                 (유)제주 늘해랑   2198.00  서귀포시  성산읍   태양광
# ..          ...                       ...       ...   ...  ...   ...
# 836   2018.9.19                후니3 태양광발전소     93.15  서귀포시  표선면   태양광
# 837  2014.10.28                희윤2 태양광발전소     99.00  서귀포시  성산읍   태양광
# 838  2014.10.29                희윤4 태양광발전소     99.28  서귀포시  성산읍   태양광
# 839  2014.10.29                희윤5 태양광발전소     99.28  서귀포시  성산읍   태양광
# 840  2014.10.29                  희윤태양광발전소     99.28  서귀포시  성산읍   태양광
#
#           사업개시일  구분    데이터기준일자
# 0     2019.4.26  육상  2020.1.20
# 1      2015.7.1  없음  2020.1.20
# 2    2014.10.16  없음  2020.1.20
# ...

# %%
solar_df['사업개시일'].isnull().sum()
# Out:
# 0

# %%
solar_df.sort_values(by = '사업개시일', ascending = True, inplace = True)
solar_df.reset_index(drop = True, inplace = True)
# Out:
# C:\Users\chunc\AppData\Local\Temp\ipykernel_10668\1314846532.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   solar_df.sort_values(by = '사업개시일', ascending = True, inplace = True)

# %%
solar_df.head()
# Out:
#         허가일자                상호  설비용량(KW) 설치행정시 설치지역 원동력종류      사업개시일  구분  \
# 0   2006.3.3              오복산전     59.87   제주시  한경면   태양광  2006.7.11  없음
# 1  2006.8.24          혜경태양광발전소     29.52   제주시  한경면   태양광  2006.9.25  없음
# 2  2007.2.21  (주)도암엔지니어링건축사사무소      3.00   제주시  한경면   태양광  2007.2.27  없음
# 3   2007.1.5            민솔라에너지     90.72   제주시  조천읍   태양광   2007.4.4  없음
# 4   2007.5.3        보타리에너지주식회사     30.00   제주시  애월읍   태양광   2007.8.6  없음
#
#      데이터기준일자
# 0  2020.1.20
# 1  2020.1.20
# 2  2020.1.20
# 3  2020.1.20
# 4  2020.1.20

# %%
solar_df['설비용량(KW)'].sum()
# Out:
# 245321.82

# %%
solar_df['위치'] = solar_df['설치행정시'] + ' ' + solar_df['설치지역']
solar_df
# Out:
# C:\Users\chunc\AppData\Local\Temp\ipykernel_10668\2833444355.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   solar_df['위치'] = solar_df['설치행정시'] + ' ' + solar_df['설치지역']
#            허가일자                상호  설비용량(KW) 설치행정시 설치지역 원동력종류      사업개시일   구분  \
# 0      2006.3.3              오복산전     59.87   제주시  한경면   태양광  2006.7.11   없음
# 1     2006.8.24          혜경태양광발전소     29.52   제주시  한경면   태양광  2006.9.25   없음
# 2     2007.2.21  (주)도암엔지니어링건축사사무소      3.00   제주시  한경면   태양광  2007.2.27   없음
# 3      2007.1.5            민솔라에너지     90.72   제주시  조천읍   태양광   2007.4.4   없음
# 4      2007.5.3        보타리에너지주식회사     30.00   제주시  애월읍   태양광   2007.8.6   없음
# ..          ...               ...       ...   ...  ...   ...        ...  ...
# ...

# %%
# 방법2
col = ['설치행정시', '설치지역']
solar_df['위치'] = solar_df[col].apply(lambda x: x[0] + ' ' + x[1], axis = 1)
# Out:
# C:\Users\chunc\AppData\Local\Temp\ipykernel_10668\1625371920.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   solar_df['위치'] = solar_df[col].apply(lambda x: x[0] + ' ' + x[1], axis = 1)

# %%
# 방법3
for i in range(len(solar_df)):
    addr = solar_df.loc[i].설치행정시 + ' ' + solar_df.loc[i].설치지역
    solar_df.loc[i, '위치'] = addr

# %%
len(solar_df['위치'].unique())
# Out:
# 46

# %%
solar_df['사업개시일'] = pd.to_datetime(solar_df['사업개시일'])
# Out:
# C:\Users\chunc\AppData\Local\Temp\ipykernel_10668\1301475687.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   solar_df['사업개시일'] = pd.to_datetime(solar_df['사업개시일'])

# %%
solar_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 811 entries, 0 to 810
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   허가일자      811 non-null    object
#  1   상호        811 non-null    object
#  2   설비용량(KW)  811 non-null    float64
#  3   설치행정시     811 non-null    object
#  4   설치지역      811 non-null    object
#  5   원동력종류     811 non-null    object
#  6   사업개시일     811 non-null    datetime64[ns]
#  7   구분        811 non-null    object
#  8   데이터기준일자   811 non-null    object
#  9   위치        811 non-null    object
# dtypes: datetime64[ns](1), float64(1), object(8)
# memory usage: 63.5+ KB

# %%
solar_df2010 = solar_df[solar_df['사업개시일'] < '2010.1.1']
solar_df2010
# Out:
#           허가일자                상호  설비용량(KW) 설치행정시  설치지역 원동력종류      사업개시일  구분  \
# 0     2006.3.3              오복산전     59.87   제주시   한경면   태양광 2006-07-11  없음
# 1    2006.8.24          혜경태양광발전소     29.52   제주시   한경면   태양광 2006-09-25  없음
# 2    2007.2.21  (주)도암엔지니어링건축사사무소      3.00   제주시   한경면   태양광 2007-02-27  없음
# 3     2007.1.5            민솔라에너지     90.72   제주시   조천읍   태양광 2007-04-04  없음
# 4     2007.5.3        보타리에너지주식회사     30.00   제주시   애월읍   태양광 2007-08-06  없음
# 5    2007.6.25                화경     45.36   제주시   조천읍   태양광 2007-09-05  없음
# 6   2007.12.31         한국중부발전(주)     50.00   제주시  삼양일동   태양광 2008-02-13  없음
# 7    2007.2.21        제주에너지 주식회사    200.00   제주시   애월읍   태양광 2008-04-18  없음
# 8   2007.12.28     (유)케이엔디태양광발전소     80.00   제주시   한경면   태양광 2008-04-21  없음
# 9   2007.12.14       번내태양광발전주식회사     90.72  서귀포시   안덕면   태양광 2008-05-13  없음
# 10  2007.12.14       번내태양광발전주식회사     90.72  서귀포시   안덕면   태양광 2008-05-13  없음
# ...

# %%
solar_df2020 = solar_df[solar_df['사업개시일'] > '2009.12.31']
solar_df2020.head()
# Out:
#          허가일자           상호  설비용량(KW) 설치행정시 설치지역 원동력종류      사업개시일  구분  \
# 32  2009.9.14  정에너지 태양광발전소     30.00   제주시  애월읍   태양광 2010-01-15  없음
# 33  2010.11.1    한국남부발전(주)      5.59   제주시  구좌읍   태양광 2010-12-21  없음
# 34  2010.4.20        해솔에너지    199.64  서귀포시  성산읍   태양광 2010-12-03  없음
# 35  2010.4.20       삼광산업개발    199.64  서귀포시  성산읍   태양광 2010-12-03  없음
# 36   2009.4.1    주식회사 파워플랜    198.00  서귀포시  표선면   태양광 2010-03-25  없음
#
#       데이터기준일자        위치
# 32  2020.1.20   제주시 애월읍
# 33  2020.1.20   제주시 구좌읍
# 34  2020.1.20  서귀포시 성산읍
# 35  2020.1.20  서귀포시 성산읍
# 36  2020.1.20  서귀포시 표선면

# %%
# 위도와 경도
geo_addr1 = solar_df['위치'].unique()
geo_addr = []
for addr in geo_addr1:
    geo_addr.append(addr.replace('시', ''))
geo_addr
# Out:
# ['제주 한경면',
#  '제주 조천읍',
#  '제주 애월읍',
#  '제주 삼양일동',
#  '서귀포 안덕면',
#  '서귀포 성산읍',
#  '서귀포 표선면',
#  '서귀포 남원읍',
#  '제주 구좌읍',
#  '제주 아라일동',
#  '제주 노형동',
#  '서귀포 대정읍',
#  '제주 이호이동',
#  '제주 삼도이동',
#  '제주 도련일동',
#  '제주 한림읍',
#  '제주 외도일동',
#  '제주 영평동',
#  '제주 용담이동',
#  '제주 회천동',
#  '서귀포 동홍동',
#  '서귀포 토평동',
#  '서귀포 하예동',
#  '서귀포 호근동',
#  '서귀포 강정동',
#  '제주 용강동',
#  '제주 해안동',
#  '서귀포 상예동',
#  '서귀포 도순동',
#  '서귀포 하효동',
#  '서귀포 서홍동',
#  '제주 도평동',
#  '제주 오라일동',
#  '서귀포 중문동',
#  '서귀포 서귀동',
#  '제주 봉개동',
#  '제주 오라이동',
#  '제주 이도일동',
#  '제주 도련이동',
#  '서귀포 색달동',
#  '제주 화북이동',
#  '제주 오등동',
#  '서귀포 서호동',
#  '서귀포 하원동',
#  '제주 아라이동',
#  '서귀포 상효동']

# %%
from geopy.geocoders import Nominatim
# 비어있는 리스트에 주소, 위도, 경도 할당
unique_addr = []
unique_lat = []
unique_lng = []

def geocoding(address):
    geolocoder = Nominatim(user_agent = 'South Korea', timeout=None)
    # address가 한글로 입력했을때 패키지에서 한글주소를 인식 못하는 경우
    geo = geolocoder.geocode(address)
    # 한글주소로 인식이 안되면
    if geo == None:
        print('geo is null')
        return 0, 0
    else:
        return geo.latitude, geo.longitude

for addr in geo_addr:
    lat, lng = geocoding(addr)

    if lat == 0 and lng == 0:
        continue
    unique_addr.append(addr)
    unique_lat.append(lat)
    unique_lng.append(lng)
    print(lat, lng)
# Out:
# 33.3305 126.21066
# 33.50888 126.66305
# 33.45079 126.3752
# 33.52345 126.599
# geo is null
# 33.4359612 126.9162804
# 33.3266709 126.831045
# geo is null
# 33.51662 126.81055
# 33.46882 126.54574
# 33.4781247 126.4754867
# 33.2330247 126.2495988
# 33.498551 126.4565213
# geo is null
# 33.5059 126.5869
# 33.39344 126.26684
# 33.4855847 126.4284514
# 33.4812 126.57106
# 33.50742 126.50615
# 33.4956 126.61479
# 33.26184 126.56804
# 33.2705286 126.5841149
# 33.24016 126.3806
# 33.25632 126.53351
# 33.24695 126.48927
# 33.47017 126.58934
# 33.44899 126.46036
# 33.26177 126.38678
# 33.2569662 126.4731036
# 33.2582539 126.6179833
# 33.25965 126.55175
# 33.47875 126.4515
# 33.49611 126.51699
# 33.262002 126.4288617
# 33.24679 126.56396
# 33.484188 126.5993497
# 33.47081 126.50991
# 33.5059 126.5278
# 33.51279 126.59604
# 33.2640931 126.4120002
# 33.50469 126.5648
# 33.46148 126.53087
# 33.25759 126.51916
# 33.2626587 126.4600239
# 33.48148 126.55055
# 33.2896254 126.5945088

# %%
ko_addr = ['서귀포 안덕면', '서귀포 남원읍', '서귀포 도순동','제주 삼도2동']
eng_addr = ["Andeok-myeon, Seogwipo-si", 'Namwon-eup, Seogwipo-si', '29beon-gil, Seogwipo-si', '7, Gija-gil, Jeju-si']

index = 0
for addr in eng_addr:
    print(ko_addr[index])
    lat, lng = geocoding(addr)
    if lat == 0 or lng == 0:
        continue
    unique_addr.append(ko_addr[index])
    unique_lat.append(lat)
    unique_lng.append(lng)
    print(lat, lng)
    index += 1
# Out:
# 서귀포 안덕면
# 33.2572438 126.3525278
# 서귀포 남원읍
# 33.28617 126.70751
# 서귀포 도순동
# 33.2471368 126.5598293
# 제주 삼도2동
# 33.4841494 126.5443579

# %%
# 전체 좌표 데이터프레임을 만들어준다
df_unique = pd.DataFrame({'주소' : unique_addr,
                         '경도(x)': unique_lng,
                         '위도(y)': unique_lat})
df_unique
# Out:
#          주소       경도(x)      위도(y)
# 0    제주 한경면  126.210660  33.330500
# 1    제주 조천읍  126.663050  33.508880
# 2    제주 애월읍  126.375200  33.450790
# 3   제주 삼양일동  126.599000  33.523450
# 4   서귀포 성산읍  126.916280  33.435961
# 5   서귀포 표선면  126.831045  33.326671
# 6    제주 구좌읍  126.810550  33.516620
# 7   제주 아라일동  126.545740  33.468820
# 8    제주 노형동  126.475487  33.478125
# 9   서귀포 대정읍  126.249599  33.233025
# 10  제주 이호이동  126.456521  33.498551
# 11  제주 도련일동  126.586900  33.505900
# 12   제주 한림읍  126.266840  33.393440
# 13  제주 외도일동  126.428451  33.485585
# 14   제주 영평동  126.571060  33.481200
# 15  제주 용담이동  126.506150  33.507420
# 16   제주 회천동  126.614790  33.495600
# 17  서귀포 동홍동  126.568040  33.261840
# 18  서귀포 토평동  126.584115  33.270529
# 19  서귀포 하예동  126.380600  33.240160
# 20  서귀포 호근동  126.533510  33.256320
# 21  서귀포 강정동  126.489270  33.246950
# 22   제주 용강동  126.589340  33.470170
# 23   제주 해안동  126.460360  33.448990
# 24  서귀포 상예동  126.386780  33.261770
# 25  서귀포 도순동  126.473104  33.256966
# ...

# %%
# 지도표시
import pandas as pd
import folium
jeju_map = folium.Map(location = [33.38, 126.55], zoom_start = 12)
print(df_unique)
for i in range(len(df_unique)):
    folium.Marker([df_unique.iloc[i][2], df_unique.iloc[i][1]], popup = df_unique.index[i]).add_to(jeju_map)
    
jeju_map.save('jeju.html')
# Out:
#          주소       경도(x)      위도(y)
# 0    제주 한경면  126.210660  33.330500
# 1    제주 조천읍  126.663050  33.508880
# 2    제주 애월읍  126.375200  33.450790
# 3   제주 삼양일동  126.599000  33.523450
# 4   서귀포 성산읍  126.916280  33.435961
# 5   서귀포 표선면  126.831045  33.326671
# 6    제주 구좌읍  126.810550  33.516620
# 7   제주 아라일동  126.545740  33.468820
# 8    제주 노형동  126.475487  33.478125
# 9   서귀포 대정읍  126.249599  33.233025
# 10  제주 이호이동  126.456521  33.498551
# 11  제주 도련일동  126.586900  33.505900
# 12   제주 한림읍  126.266840  33.393440
# 13  제주 외도일동  126.428451  33.485585
# 14   제주 영평동  126.571060  33.481200
# 15  제주 용담이동  126.506150  33.507420
# 16   제주 회천동  126.614790  33.495600
# 17  서귀포 동홍동  126.568040  33.261840
# 18  서귀포 토평동  126.584115  33.270529
# 19  서귀포 하예동  126.380600  33.240160
# 20  서귀포 호근동  126.533510  33.256320
# 21  서귀포 강정동  126.489270  33.246950
# 22   제주 용강동  126.589340  33.470170
# 23   제주 해안동  126.460360  33.448990
# 24  서귀포 상예동  126.386780  33.261770
# 25  서귀포 도순동  126.473104  33.256966
# ...

# %%
# 반복문 연습
for i in range(5):
    if i == 2:
        continue
    print(i)
# Out:
# 0
# 1
# 3
# 4

# %%
k = 0
while True:
    k += 1
    
    if k == 2:
        print('continue next')
        continue
    
    if k > 4:
        break
        
    print(k)
# Out:
# 1
# continue next
# 3
# 4

# %%
# 팰린드롬 연습
def is_palindrome(word):
    lenStr = len(word)
    palin = True
    for i in range(0, lenStr // 2):
        if word[i] == word[lenStr - (i + 1)]:
            continue
        else:
            palin = False
    return palin
print(is_palindrome('result'))
print(is_palindrome('토마토'))
print(is_palindrome('aabbcc'))
print(is_palindrome('kyayk'))
# Out:
# False
# True
# False
# True

# %%
def is_palindrome(word):
    return word == word[::-1]

print(is_palindrome('result'))
print(is_palindrome('토마토'))
print(is_palindrome('aabbcc'))
print(is_palindrome('kyayk'))
# Out:
# False
# True
# False
# True

# %%
DEBUG = False
def is_palindrome(word):
    lenStr = len(word)
    palin = True
    
    for i in range(0, lenStr // 2):
        if DEBUG:
            print(word[i], word[lenStr - (i + 1)])
        if word[i] == word[lenStr - (i + 1)]:
            continue
        else:
            palin = False
    return palin

def resultPrint(palin):
    if palin:
        print('팰린드럼 문자열이다')
    else:
        print('팰린드롬 문자열이 아니다')
        
import pandas as pd
csvFile = 'C:/Users/chunc/Desktop/취업캠프/python/python/palindrome.csv'
df = pd.read_csv(csvFile, encoding = 'euc-kr')
for text in df['text']:
    palin = is_palindrome(text)
    resultPrint(palin)
# Out:
# 팰린드롬 문자열이 아니다
# 팰린드롬 문자열이 아니다
# 팰린드럼 문자열이다
# 팰린드럼 문자열이다
# 팰린드럼 문자열이다
# 팰린드럼 문자열이다
# 팰린드롬 문자열이 아니다
# 팰린드럼 문자열이다
# 팰린드럼 문자열이다

# %%
df['result'] = df['text'].apply(is_palindrome)
print(df)
# Out:
#      text  label  result
# 0    test      0   False
# 1  aabbcc      0   False
# 2   12321      1    True
# 3   kayak      1    True
# 4     토마토      1    True
# 5  acbbca      1    True
# 6  insert      0   False
# 7     라라라      1    True
# 8   senes      1    True
