# %% [markdown]
# # 1. CLI 기초

# %% [markdown]
# ## 1. Git 설치

# %% [markdown]
# ### (1) Windows(윈도우)

# %% [markdown]
# * Git 설치 후 윈도우 탐색기를 연다.(윈도우키 + e)
# * 'c:/사용자(users)/현재 사용자 계정' 으로 이동한다.
# * Git Bash창에 아래 화면처럼 HOME폴더를 의미하는 ~표시가 있다면 정상이다.
#     (~표시가 없거나, 뒤에 글자가 추가적으로 나타난다면 잘못된 경로일 수 있다.)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### (2) Mac(맥)

# %% [markdown]
# * Git이 기본적으로 내장되어 있기 떄문에, 별도의 설치가 필요 없다.
# * Spotlight(검색)를 연다, (화면 우측 상단의 돋보기 혹은 command + spacebar)
# * terminal을 검색하여 터미널을 연다.
# * 터미널을 열면 기본적으로 HOME폴더로 경로가 설정되어 있다. (/User/현재 사용자 계정)
# * open .라고 입력하여 HOME 폴더를 연다.

# %% [markdown]
# ## 2. GUI vs CLI

# %% [markdown]
# ### 1. GUI와 CLI

# %% [markdown]
# #### (1) GUI

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### (2) CLI

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 1. **GUI(Graphic User Interface)**: 그래픽을 통해 사용자와 컴퓨터가 상호 작용하는 방식
# 2. **CLI(Command Line Interface)**: 터미널을 통해 사용자와 컴퓨터가 상호 작용하는 방식

# %% [markdown]
# ### 2. CLI를 사용하는 이유

# %% [markdown]
# new 라는 이름으로 새 폴더를 생성한다고 가정하자.
# 1. GUI를 사용하는 경우(4단계): 마우스 우클릭 -> 새로 만들기 -> vhfej -> new 작성
# 2. CLI를 사용하는 경우(1단계): mkdir new

# %% [markdown]
# GUI는 CLI에 비해 사용하기 쉽지만 단계가 많고 컴퓨터의 성능을 더 많이 소모한다.<br>
#     또한, CLI는 GUI로는 불가능한, 많은 세부적인 기능을 사용할 수 있다.

# %% [markdown]
# ### 3. Git Bash를 사용하는 이유

# %% [markdown]
# #### 1. 명령어의 통일을 위해서
#     * UNIX계열 운영체제의 명령어와 Windows의 명령어의 차이가 존재
#     * Git Bash라고 하는 일종의 번역기를 통해 Windows에서도 UNIX 계열 운영체제의 터미널 명령어를 사용하기 위함
#
#
# #### 2. UNIX 계열 운영체제의 명령어를 더 많이 쓰기 때문이다.
#     * 개발자 입장에서는 Windows보다는 UNIX계열 운영체제 기반의 프로그램이 훨씬 많다.
#     * 개발 시장에서는 UNIX계열 운영체제가 더 많이 사용되기 때문에, Git Bash를 통해서 UNIX계열 운영체제의 터미널 명령어를 연습한다.

# %% [markdown]
# ## 3. 경로

# %% [markdown]
# ### 1. 루트, 홈 디렉토리

# %% [markdown]
# #### 1. 루트 디렉토리(Root Directory, /)
#     * 모든 파일과 폴더를 담고 있는 최상위 폴더
#     * Windows의 경우 c드라이브를 의미

# %% [markdown]
# #### 2. 홈 디렉토리(Home Directory, ~)
#     * Tilde(틸드)라고도 하며, 현재 로그인 된 사용자의 홈 폴더
#     * Windows -> C:/사용자(Users)/현재 사용자 계정
#     * Mac -> /Users/현재 사용자 계정

# %% [markdown]
# ### 2. 절대 경로와 상대 경로

# %% [markdown]
# 1. 절대경로: 루트 디렉토리로 목적 지점까지 거치는 모든 경로를 전부 작성
#     * C:/Users/chunc/Desktop
# 2. 상대경로: 현재 작업하고 있는 디렉토리를 기준으로 계산된 상대적 위치를 작성
#     * 현재 작업 디렉토리가 C:/Users이면
#     * 윈도우 바창 화면으로의 상대 경로는 chunc/Desktop
#     * 현재 작업 디렉토리가 변경되면 상대경로도 변경된다.
#     * ./: 현재 작업하고 있는 폴더를 의미
#     * ../: 현재 작업하고 있는 폴더의 부모 폴더를 의미

# %% [markdown]
# ## 4. 터미널 명령어

# %% [markdown]
# ### touch

# %% [markdown]
# * 파일을 생성하는 명령어
# * 띄어쓰기로 구분하여 여러 파일을 한꺼번에 생성 가능
# * 숨김 파일을 만들기 위해서는 .을 파일 명 앞에 붙인다.

# %%
$ touch text.txt

# %% [markdown]
# ### mkdir

# %% [markdown]
# * make directory
# * 새 폴더를 생성하는 명령어
# * 띄어쓰기로 구분하여 여러 폴더를 한꺼번에 생성 가능
# * 폴더 이름 사이에 공백을 넣고 싶다면 따옴표로 묶어서 입력

# %%
$ mkdir folder
$ mkdir 'happy hacking'

# %% [markdown]
# ### ls

# %% [markdown]
# * list segments
# * 현재 작업 중인 디렉토리의 폴더/파일 목록을 보여주는 명령어
# * -a: all옵션, 숨김파일까지 모두 보여준다.
# * -l: long옵션, 용량, 수정 날짜 등 파일 정보를 자세히 보여준다.

# %%
# 기본 사용
$ ls 

# all 옵션
$ ls -a

# all, long 옵션 함께 적용
$ ls -a -l

# 여러 옵션 축약 가능
$ ls -al

# %% [markdown]
# ### mv

# %% [markdown]
# * move
# * 폴더/파일을 다른 폴더 내로 이동하거나 이름을 변경하는 명령어
# * 단, 다른 폴더로 이동할 떄는 작성한 폴더가 반드시 있어야 한다. 만약 없다면 이름이 바뀐다.

# %%
# text.txt를 folder 폴더 안에 넣을 때
$ mv text.txt folder

# text1.txt의 이름을 text2.txt로 바꿀 때
$ mv text1.txt text2.txt

# %% [markdown]
# ### cd

# %% [markdown]
# - change directory
# - 현재 작업 중인 디렉토리를 변경하는 명령어
# - `cd ~` 를 입력하면 홈 디렉토리로 이동합니다. (단순히 `cd` 라고만 입력해도 동일)
# - `cd ..` 를 입력하면 부모 디렉토리로 이동(위로 가기)
# - `cd -` 를 입력하면 바로 전 디렉토리로 이동(뒤로 가기)

# %%
# 현재 작업 중인 디렉토리에 있는 folder 폴더로 이동
$ cd folder

# 절대 경로를 통한 디렉토리 변경
$ cd C:/Users/kyle/Desktop

# 상대 경로를 통한 디렉토리 변경
$ cd ../parent/child

# %% [markdown]
# ### rm

# %% [markdown]
# - remove
# - 폴더/파일 지우는 명령어
# - GUI와 달리 휴지통으로 이동하지 않고, 바로 `완전 삭제한다.
# - `*(asterisk, wildcard)`를 사용해서 `rm *.txt` 라고 입력하면 txt 파일 전체를 다 지운다.
# - `-r` : recursive 옵션. 폴더를 지울 때 사용

# %%
$ rm test.txt
$ rm -r folder

# %% [markdown]
# ### start, open

# %% [markdown]
# - 폴더/파일을 여는 명령어
# - `Windows`에서는 start를, `Mac`에서는 open을 사용할 수 있다.

# %%
# Windows
$ start test.txt

# Mac
$ open test.txt

# %% [markdown]
# ### 알아두면 좋은 단축키

# %% [markdown]
# - `위, 아래 방향키` : 과거에 작성했던 명령어 조회
# - `tab` : 폴더/파일 이름 자동 완성
# - `ctrl + a` : 커서가 맨 앞으로 이동
# - `ctrl + e` : 커서가 맨 뒤로 이동
# - `ctrl + w` : 커서가 앞 단어를 삭제
# - `ctrl + l` : 터미널 화면을 깨끗하게 청소 (스크롤 올리면 과거 내역 조회 가능)
# - `ctrl + insert` : 복사
# - `shift + insert` : 붙여넣기

# %% [markdown]
# ## 5. Git 기초

# %% [markdown]
# ### 1. Git 초기 설정

# %% [markdown]
# 최초 한 번만 설정한다. 매번 Git을 사용할 떄마다 설정할 필요는 없다.
# 1. 누가 커밋 기록을 남겼는지 확인할 수 있도록 이름과 이메일을 설정. <br>
# 작성자를 수정하고 싶을 때는 이름, 메일 주소만 다르게 하여 동일하게 입력

# %%
$ git config --global user.name "github nickname"
$ git config --global user.email "user email"

# %% [markdown]
# 작성자가 올바르게 설정되었는지 확인

# %%
$ git config --global -l

# %%
$ git config --global --list

# %% [markdown]
# ### 2. 기본명령어

# %% [markdown]
# #### 로컬 저장소

# %% [markdown]
# * Working Directory(= Working Tree): 사용자의 일반적인 작업이 일어나는 곳
# * Staging Area(= Index): 커밋을 위한 파일 및 폴더가 추가되는 곳
# * Repository: staging area에 있던 파일 및 폴더의 변경사항(커밋)을 저장하는 곳
# * Git은 Working Directory -> Staging Area -> Repository 의 과정으로 버전 관리 수행

# %% [markdown]
# #### git init

# %%
$ git init

# %% [markdown]
# * 현재 작업중인 디렉토리를 Git으로 관리한다는 명령어
# * .git이라는 숨김 폴더를 생성, 터미널에는 (master)라고 표기된다.
# * Mac OS의 경우 (master)가 표시되지 않는데, Terminal 업그레이드를 통해 표기항 수 있다.

# %% [markdown]
# ** 주의사항**
#
# 1. 이미 Git저장소인 폴더 내에 또 다른 Git저장소를 만들지 않는다.(중첩 금지) <br>
# 즉, 터미널에 이미(master)가 있다면, git init을 절대 입력하면 안된다.
# 2. 절대로 홈 디렉토리에서 git init을 하지 않는다!. 터미널의 경로가 ~인지 pwd를 수시로 입력하며 확인하는 습관을 들이자.

# %% [markdown]
# #### git status

# %%
$ git status

# %% [markdown]
# * Working Directory와 Staging Area에 있는 파일의 현재 상태를 알려주는 명령어
# * 어떤 작업을 시행하기 전에 수시로 status를 확인하면 좋다.
# * 상태
#     1. `Untracked` : Git이 관리하지 않는 파일 (한번도 Staging Area에 올라간 적 없는 파일)
#     2. `Tracked` : Git이 관리하는 파일
#         1. `Unmodified` : 최신 상태
#         2. `Modified` : 수정되었지만 아직 Staging Area에는 반영하지 않은 상태
#         3. `Staged` : Staging Area에 올라간 상태

# %% [markdown]
# #### git add

# %%
# 특정 파일
$ git add a.txt

# 특정 폴더
$ git add my_folder/

# 현재 디렉토리에 속한 파일/폴더 전부
$ git add .

# %% [markdown]
# * Working Directory에 있는 파일을 Staging Area로 올리는 명령어
# * Git이 해당 파일을 추적(관리)할 수 있도록 만든다.
# * Untracked, Modified → Staged 로 상태를 변경

# %% [markdown]
# #### git commit

# %%
$ git commit -m "first commit"

# %% [markdown]
# * Staging Area에 올라온 파일의 변경사항을 하나의 버전(커밋)으로 저장하는 명령어
# * 커밋 메세지는 현재 변경 사항들을 잘 나타낼 수 있도록 '의미'있게 작성하는 것을 권장함
# * 각각의 커밋은 SHA-1알고리즘에 의해 반환 된 고유의 해시 값 ID를 가진다.
# * (root-commit)은 해당 커밋이 최초의 커밋 일 때만 표시된다. 이후 커밋부터는 사라진다.

# %% [markdown]
# #### git log

# %%
$ git log

# %% [markdown]
# * 커밋의 내역(ID, 작성자, 시간, 메세지 등)을 조회할 수 있는 명령어
# * 옵션
#     * --oneline: 한 줄로 축약해서 보여준다.
#     * --graph: 브랜치와 머지 내역을 그래프로 보여준다.
#     * --all: 현재 브랜치를 포함한 모든 브랜치의 내역을 보여준다.
#     * --reverse: 커밋 내역의 순서를 반대로 보여준다.(최신이 가장 아해)
#     * -p: 파일의 변경 내용도 같이 보여준다.
#     * -2: 원하는 갯수만큼의 내역을 보여준다(2가 아닌 임의숫자 가능)

# %% [markdown]
# ### Git명령어 구조

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 6. Github

# %% [markdown]
# ### 1. 원격저장소

# %% [markdown]
# Github의 원격 저장소를 이용하여 내 컴퓨터와 로컬 저장소를 다른 사람과 공유할 수 있다.

# %% [markdown]
# #### 1. Github에서 원격 저장소 생성

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 화면 오른쪽 상단의 '+'버튼 또는 초록색 버튼을 통해 New repository를 클릭한다.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 저장소의 이름, 설명, 공개여부를 선택하고 Create repository를 클릭한다

# %% [markdown]
# #### 2. 로컬 저장소와 원격 저장소 연결

# %% [markdown]
# 1. 원격 저장소가 잘 생성되었는지 확인 후, 저장소의 주소를 복사한다.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 2. 실습 시에 생성한 TIL폴더에 git init을 통해 로컬 저장소를 만들어준다.

# %% [markdown]
#  **git remote** <br>
# 로컬 저장소에 원격 저장소를 등록, 조회, 삭제 할 수 있는 명령어
# 1. 등록: 'git remote add origin <주소>'의 형식으로 작성

# %%
$ git remote add origin https://github.com/jcm821/TIL.git

# %% [markdown]
# 2. 조회: 'git remote -v'로 작성

# %%
$ git remote -v

# %% [markdown]
# 3. 삭제: 'git remote rm origin' 또는 'git remote remove origin'으로 작성

# %%
$ git remote rm origin

# %% [markdown]
# 이때, 로컬 저장소와 원격 저장소의 연결을 끊는 것이지, 원격 저장소 자체를 삭제하는 게 아니다.

# %% [markdown]
# #### 3. 원격 저장소에 업로드

# %% [markdown]
# 원격 저장소에 업로드를 하기 위해서는 먼저 파일을 커밋한 상태여야 한다.

# %% [markdown]
# **git push**

# %% [markdown]
# * 로컬 저장소의 커밋을 원격 저장소에 업로드하는 명령어
# * 'git push <저장소이름(origin)> <브랜치 이름>' 형식으로 작성
# * '-u' 옵션을 사용하면, 두 번째 커밋부터는 저장소이름, 브랜치 이름을 생략 가능하다.

# %%
$ git push origin master

# %% [markdown]
# 이후 로그인과정과 정상 업로드가 되었는지 확인하면 Github에 커밋을 정상적으로 완료했다고 볼 수 있다.
