# %% [markdown]
# # 태블로 적응하기

# %% [markdown]
# ## 참고 블로그
# * https://help.tableau.com/current/pro/desktop/ko-kr/buildexamples_maps.htm
# * https://gnuykob.tistory.com/14
# * https://jjohr123.tistory.com/7

# %% [markdown]
# ## 자치구별 1인 가구수 합계

# %% [markdown]
# - 지도 형태로도 표출하고 싶은 경우 데이터 원본 - 자치구의 abc부분을 클릭 후 지리적 역할을 부여하면 된다.
# - 구역을 누르면 해당되는 1인가구수의 합계가 나온다
# - 필터가 걸린채로 저장된 엑셀 파일이라 강서구와 중구가 제대로 표현이 안된 줄 알았음

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# * 다시 보니 우측 하단에 알 수 없는 정보 표시에 중구와 강서구의 위, 경도값을 인식못하는 오류메시지 발견 → 위치 편집 - 주/시/도 부분을 서울특별시로 고정하니 문제 해결
# * 맵 배경 등의 세부사항을 수정하고자 하면 상단 맵 버튼에서 실시하면 된다.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 자치구별, 성별 1인가구수 합계

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 자치구별, 연령대별 1인가구수

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## 자치구별, 성별 평균 쇼핑 사용일수

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## 자치구별, 연령대별 평균 쇼핑 서비스 사용일수

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 대쉬보드 표현

# %% [markdown]
# - 위의 결과들을 대시보드에 표현하면 아래와 같이 나온다.
# - ‘부동’ 방식을 사용하여 크기 조절
# - 대시보드-서식을 통해 백그라운드에 색상이나 구글링 해보니 배경화면을 넣을 수도 있는 듯 함

# %% [markdown]
# ![image-4.png](attachment:image-4.png)
